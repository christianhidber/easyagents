# %%
import sys
import warnings

warnings.filterwarnings('ignore')

if 'google.colab' in sys.modules:
    # !apt-get install xvfb >/dev/null
    # !pip install pyvirtualdisplay >/dev/null    
    
    from pyvirtualdisplay import Display
    Display(visible=0, size=(960, 720)).start()    

    sys.path.append('..')

    # !pip install easyagent
    
from easyagents.agents import get_backends, DqnAgent, RandomAgent, PpoAgent, ReinforceAgent
from easyagents.callbacks import log, plot, duration

get_backends()
# Out:
# WARNING:tensorflow:
#
#   TensorFlow's `tf-nightly` package will soon be updated to TensorFlow 2.0.
#
#   Please upgrade your code to TensorFlow 2.0:
#     * https://www.tensorflow.org/beta/guide/migration_guide
#
#   Or install the latest stable TensorFlow 1.X release:
#     * `pip install -U "tensorflow==1.*"`
#
#   Otherwise your code may be broken by the change.
#
#
# WARNING:tensorflow:From c:\dev\github\easyagents\env\lib\site-packages\tensorforce\core\module.py:31: The name tf.enable_resource_variables is deprecated. Please use tf.compat.v1.enable_resource_variables instead.
#
# WARNING:tensorflow:From c:\dev\github\easyagents\env\lib\site-packages\tensorforce\core\optimizers\tf_optimizer.py:46: The name tf.train.AdadeltaOptimizer is deprecated. Please use tf.compat.v1.train.AdadeltaOptimizer instead.
# ['default', 'tfagents', 'tensorforce']

# %%
backend='tensorforce'

# %% [markdown]
# ### Random

# %%
randomAgent = RandomAgent('CartPole-v0', backend=backend)
randomAgent.train()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-3d5893465fb6> in <module>
#       1 randomAgent = RandomAgent('CartPole-v0', backend=backend)
# ----> 2 randomAgent.train()
#
# C:\Dev\GitHub\easyagents\easyagents\agents.py in train(self, callbacks, num_iterations, max_steps_per_episode, num_episodes_per_eval, train_context, default_plots)
#     450             train_context.learning_rate = 1
#     451
# --> 452         super().train(train_context=train_context, callbacks=callbacks, default_plots=default_plots)
#     453         return train_context
#     454
#
# C:\Dev\GitHub\easyagents\easyagents\agents.py in train(self, train_context, callbacks, default_plots)
#     164             callbacks = [callbacks]
#     165         callbacks = self._prepare_callbacks(callbacks, default_plots, [plot.Loss(), plot.Steps(), plot.Rewards()])
# --> 166         self._backend_agent.train(train_context=train_context, callbacks=callbacks)
#     167
#     168
#
# C:\Dev\GitHub\easyagents\easyagents\backends\core.py in train(self, train_context, callbacks)
#     382             monitor._MonitorEnv._register_backend_agent(self)
#     383             self._on_train_begin()
# --> 384             self.train_implementation(self._agent_context.train)
#     385             self._on_train_end()
#     386         finally:
#
# C:\Dev\GitHub\easyagents\easyagents\backends\tforce.py in train_implementation(self, train_context)
#     192             seed=self.model_config.seed,
#     193         )
# --> 194         self._train_with_tensorforce_runner(train_env, tc)
#     195
#     196 class BackendAgentFactory(easyagents.backends.core.BackendAgentFactory):
#
# C:\Dev\GitHub\easyagents\easyagents\backends\tforce.py in _train_with_tensorforce_runner(self, train_env, train_context)
#      89                    evaluation_frequency=None,
#      90                    evaluation=False,
# ---> 91                    num_evaluation_iterations=0
#      92                    )
#      93         if not train_context.training_done:
#
# c:\dev\github\easyagents\env\lib\site-packages\tensorforce\execution\runner.py in run(self, num_episodes, num_timesteps, max_episode_timesteps, num_repeat_actions, callback, callback_episode_frequency, callback_timestep_frequency, use_tqdm, mean_horizon, evaluation, evaluation_callback, evaluation_frequency, max_evaluation_timesteps, num_evaluation_iterations)
#     223             if not self.run_episode(
#     224                 environment=self.environment, max_timesteps=self.max_episode_timesteps,
# --> 225                 evaluation=self.evaluation
#     226             ):
#     227                 return
#
# c:\dev\github\easyagents\env\lib\site-packages\tensorforce\execution\runner.py in run_episode(self, environment, max_timesteps, evaluation)
#     307             # Retrieve actions from agent
#     308             agent_start = time.time()
# --> 309             actions = self.agent.act(states=states, evaluation=evaluation)
#     310             self.episode_agent_second += time.time() - agent_start
#     311             self.episode_timestep += 1
#
# c:\dev\github\easyagents\env\lib\site-packages\tensorforce\agents\agent.py in act(self, states, parallel, deterministic, independent, evaluation, query, **kwargs)
#     290             actions, self.timestep = self.model.act(
#     291                 states=states, auxiliaries=auxiliaries, parallel=parallel,
# --> 292                 deterministic=deterministic, independent=independent, **kwargs
#     293             )
#     294
#
# c:\dev\github\easyagents\env\lib\site-packages\tensorforce\core\module.py in fn(query, **kwargs)
#     554
#     555             # TensorFlow session call
# --> 556             fetched = self.monitored_session.run(fetches=fetches, feed_dict=feed_dict)
#     557
#     558             return fetched
#
# c:\dev\github\easyagents\env\lib\site-packages\tensorflow_core\python\training\monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     752         feed_dict=feed_dict,
#     753         options=options,
# --> 754         run_metadata=run_metadata)
#     755
#     756   def run_step_fn(self, step_fn):
#
# c:\dev\github\easyagents\env\lib\site-packages\tensorflow_core\python\training\monitored_session.py in run(self, *args, **kwargs)
#    1343   def run(self, *args, **kwargs):
#    1344     try:
# -> 1345       return self._sess.run(*args, **kwargs)
#    1346     except _PREEMPTION_ERRORS:
#    1347       raise
#
# c:\dev\github\easyagents\env\lib\site-packages\tensorflow_core\python\training\monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1416         feed_dict=feed_dict,
#    1417         options=options,
# -> 1418         run_metadata=run_metadata)
#    1419
#    1420     for hook in self._hooks:
#
# c:\dev\github\easyagents\env\lib\site-packages\tensorflow_core\python\training\monitored_session.py in run(self, *args, **kwargs)
#    1174
#    1175   def run(self, *args, **kwargs):
# -> 1176     return self._sess.run(*args, **kwargs)
#    1177
#    1178   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# c:\dev\github\easyagents\env\lib\site-packages\tensorflow_core\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# c:\dev\github\easyagents\env\lib\site-packages\tensorflow_core\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# c:\dev\github\easyagents\env\lib\site-packages\tensorflow_core\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# c:\dev\github\easyagents\env\lib\site-packages\tensorflow_core\python\client\session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# c:\dev\github\easyagents\env\lib\site-packages\tensorflow_core\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# c:\dev\github\easyagents\env\lib\site-packages\tensorflow_core\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
randomAgent.play(num_episodes=3)

# %% [markdown]
# ### Dqn

# %%
# %%time

dqnAgent = DqnAgent('CartPole-v0')
dqnAgent.train(num_iterations=10000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# C:\Dev\GitHub\easyagents\easyagents\agents.py in train(self, callbacks, num_iterations, max_steps_per_episode, num_steps_per_iteration, num_steps_buffer_preload, num_steps_sampled_from_buffer, num_iterations_between_log, num_iterations_between_eval, num_episodes_per_eval, learning_rate, train_context, default_plots)
#     274             train_context.learning_rate = learning_rate
#     275
# --> 276         super().train(train_context=train_context, callbacks=callbacks, default_plots=default_plots)
#     277         return train_context
#     278
#
# C:\Dev\GitHub\easyagents\easyagents\agents.py in train(self, train_context, callbacks, default_plots)
#     164             callbacks = [callbacks]
#     165         callbacks = self._prepare_callbacks(callbacks, default_plots, [plot.Loss(), plot.Steps(), plot.Rewards()])
# --> 166         self._backend_agent.train(train_context=train_context, callbacks=callbacks)
#     167
#     168
#
# C:\Dev\GitHub\easyagents\easyagents\backends\core.py in train(self, train_context, callbacks)
#     382             monitor._MonitorEnv._register_backend_agent(self)
#     383             self._on_train_begin()
# --> 384             self.train_implementation(self._agent_context.train)
#     385             self._on_train_end()
#     386         finally:
#
# C:\Dev\GitHub\easyagents\easyagents\backends\tfagents.py in train_implementation(self, train_context)
#     176             self.on_train_iteration_begin()
#     177             for _ in range(dc.num_steps_per_iteration):
# --> 178                 self.collect_step(env=train_env, policy=tf_agent.collect_policy, replay_buffer=replay_buffer)
#     179             trajectories, _ = next(iter_dataset)
#     180             tf_loss_info = tf_agent.train(experience=trajectories)
#
# C:\Dev\GitHub\easyagents\easyagents\backends\tfagents.py in collect_step(self, env, policy, replay_buffer)
#     123         next_time_step = env.step(action_step.action)
#     124         traj = trajectory.from_transition(time_step, action_step, next_time_step)
# --> 125         replay_buffer.add_batch(traj)
#     126
#     127     # noinspection DuplicatedCode
#
# c:\dev\github\easyagents\env\lib\site-packages\tf_agents\replay_buffers\replay_buffer.py in add_batch(self, items)
#      69       Adds `items` to the replay buffer.
#      70     """
# ---> 71     return self._add_batch(items)
#      72
#      73   def get_next(self,
#
# c:\dev\github\easyagents\env\lib\site-packages\tf_agents\replay_buffers\tf_uniform_replay_buffer.py in _add_batch(self, items)
#     191
#     192     with tf.device(self._device), tf.name_scope(self._scope):
# --> 193       id_ = self._increment_last_id()
#     194       write_rows = self._get_rows_for_id(id_)
#     195       write_id_op = self._id_table.write(write_rows, id_)
#
# c:\dev\github\easyagents\env\lib\site-packages\tf_agents\replay_buffers\tf_uniform_replay_buffer.py in _increment_last_id(self, increment)
#     510     def _assign_add():
#     511       return self._last_id.assign_add(increment).value()
# --> 512     return self._last_id_cs.execute(_assign_add)
#     513
#     514   def _get_last_id(self):
#
# c:\dev\github\easyagents\env\lib\site-packages\tensorflow_core\python\ops\critical_section_ops.py in execute(self, fn, exclusive_resource_access, name)
#     221       # Ensure that mutex locking only happens *after* all args and
#     222       # kwargs have been executed.  This avoids certain types of deadlocks.
# --> 223       lock = gen_resource_variable_ops.mutex_lock(self._handle)
#     224
#     225       if not context.executing_eagerly():
#
# c:\dev\github\easyagents\env\lib\site-packages\tensorflow_core\python\ops\gen_resource_variable_ops.py in mutex_lock(mutex, name)
#     413       _result = _pywrap_tensorflow.TFE_Py_FastPathExecute(
#     414         _ctx._context_handle, _ctx._thread_local_data.device_name,
# --> 415         "MutexLock", name, _ctx.post_execution_callbacks, mutex)
#     416       return _result
#     417     except _core._FallbackException:
#
# KeyboardInterrupt:

# %%
dqnAgent.play(num_episodes=3)

# %% [markdown]
# ### Ppo

# %%
# %%time

ppoAgent = PpoAgent('CartPole-v0', backend=backend)
ppoAgent.train(num_iterations=10)

# %%
ppoAgent.play(num_episodes=3)

# %% [markdown]
# ### Reinforce

# %%
# %%time

reinforceAgent = ReinforceAgent('CartPole-v0', backend=backend)
reinforceAgent.train(num_iterations=10)

# %%
reinforceAgent.play(num_episodes=3)
