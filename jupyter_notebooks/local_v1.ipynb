# %%
import easyagents 
from easyagents.callbacks.duration import Fast as Fast
from easyagents.callbacks.log import LogIteration, LogStep
from easyagents.callbacks.plot import PlotLoss, PlotSteps, PlotRewards

# %%
agent=easyagents.PpoAgent("CartPole-v0")
#agent.train([Fast(),LogIteration()])
agent.train([Fast(),PlotLoss(), PlotSteps(), PlotRewards(), PlotLoss()])
#agent.play(LogStep())

# %%
1+1
# Out:
# 2
