# %%
import easyagents 
from easyagents.callbacks.duration import Fast, SingleEpisode
from easyagents.callbacks.log import LogIteration, LogStep, LogAgent, LogCallbacks
from easyagents.callbacks.plot import PlotLoss, PlotSteps, PlotRewards, PlotState

# %%
agent=easyagents.PpoAgent("CartPole-v0")
agent.train([Fast(),LogAgent(), PlotLoss(), PlotLoss(ylim=(-0.01,0.1)),PlotRewards(), PlotState()])

# %%
agent.play(PlotState())

# %%
agent=easyagents.PpoAgent("CartPole-v0")
agent.train([Fast(), PlotState()])
