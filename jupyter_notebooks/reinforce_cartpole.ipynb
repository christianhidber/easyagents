# %% [markdown]
# # CartPole Gym environment with TfAgents

# %% [markdown]
# ##### suppress package warnings, prepare matlab, if in colab: load additional packages for rendering

# %%
import sys
import warnings
import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')

if 'google.colab' in sys.modules:
    # !apt-get install xvfb >/dev/null
    # !pip install pyvirtualdisplay >/dev/null    
    
    from pyvirtualdisplay import Display
    Display(visible=0, size=(960, 720)).start()

# %%
# only for local installation
sys.path.append('..')

# %%
# !pip install easyagents >/dev/null

# %%
from easyagents.agents import DqnAgent, RandomAgent, ReinforceAgent
from easyagents.callbacks import log, plot, duration
# Out:
# c:\dev\github\easyagents\env\lib\site-packages\gym\logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# WARNING: Logging before flag parsing goes to stderr.
# W0915 00:11:20.867201 10480 __init__.py:689]
#
#   TensorFlow's `tf-nightly` package will soon be updated to TensorFlow 2.0.
#
#   Please upgrade your code to TensorFlow 2.0:
#     * https://www.tensorflow.org/beta/guide/migration_guide
#
#   Or install the latest stable TensorFlow 1.X release:
#     * `pip install -U "tensorflow==1.*"`
#
#   Otherwise your code may be broken by the change.

# %%
reinforce_agent = ReinforceAgent('CartPole-v0')
reinforce_agent.train(duration.Fast())

# %%
reinforce_agent.play([plot.Actions(),plot.Rewards()],num_episodes=10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-6cf493e13389> in <module>
# ----> 1 reinforce_agent.play([plot.Actions(),plot.Rewards()],num_episodes=10)
#
# C:\Dev\GitHub\easyagents\easyagents\agents.py in play(self, callbacks, num_episodes, max_steps_per_episode, play_context, default_plots)
#     483             play_context.max_steps_per_episode = max_steps_per_episode
#     484             play_context.num_episodes = num_episodes
# --> 485         super().play(play_context=play_context, callbacks=callbacks, default_plots=default_plots)
#     486         return play_context
#     487
#
# C:\Dev\GitHub\easyagents\easyagents\agents.py in play(self, play_context, callbacks, default_plots)
#     119             callbacks = [callbacks]
#     120         callbacks = self._prepare_callbacks(callbacks, default_plots, [plot.Steps(), plot.Rewards()])
# --> 121         self._backend_agent.play(play_context=play_context, callbacks=callbacks)
#     122         return play_context
#     123
#
# C:\Dev\GitHub\easyagents\easyagents\backends\core.py in play(self, play_context, callbacks)
#     327             monitor._MonitorEnv._register_backend_agent(self)
#     328             self._on_play_begin()
# --> 329             self.play_implementation(self._agent_context.play)
#     330             self._on_play_end()
#     331         finally:
#
# C:\Dev\GitHub\easyagents\easyagents\backends\tfagents.py in play_implementation(self, play_context)
#      94             while not time_step.is_last():
#      95                 action_step = self._trained_policy.action(time_step)
# ---> 96                 time_step = self._eval_env.step(action_step.action)
#      97             self.on_play_episode_end()
#      98             if play_context.play_done:
#
# c:\dev\github\easyagents\env\lib\site-packages\tf_agents\environments\tf_environment.py in step(self, action)
#     230           corresponding to `observation_spec()`.
#     231     """
# --> 232     return self._step(action)
#     233
#     234   def render(self):
#
# c:\dev\github\easyagents\env\lib\site-packages\tensorflow_core\python\autograph\impl\api.py in wrapper(*args, **kwargs)
#     290   def wrapper(*args, **kwargs):
#     291     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 292       return func(*args, **kwargs)
#     293
#     294   if inspect.isfunction(func) or inspect.ismethod(func):
#
# c:\dev\github\easyagents\env\lib\site-packages\tf_agents\environments\tf_py_environment.py in _step(self, actions)
#     216                 (self.batch_size, action.shape, action))
#     217       outputs = tf.numpy_function(
# --> 218           _step_py, flat_actions, self._time_step_dtypes, name='step_py_func')
#     219       step_type, reward, discount = outputs[0:3]
#     220       flat_observations = outputs[3:]
#
# c:\dev\github\easyagents\env\lib\site-packages\tensorflow_core\python\ops\script_ops.py in numpy_function(func, inp, Tout, name)
#     498 @tf_export("numpy_function")
#     499 def numpy_function(func, inp, Tout, name=None):
# --> 500   return py_func_common(func, inp, Tout, stateful=True, name=name)
#     501
#     502
#
# c:\dev\github\easyagents\env\lib\site-packages\tensorflow_core\python\ops\script_ops.py in py_func_common(func, inp, Tout, stateful, name)
#     462   """
#     463   if context.executing_eagerly():
# --> 464     result = func(*[x.numpy() for x in inp])
#     465     result = nest.flatten(result)
#     466
#
# c:\dev\github\easyagents\env\lib\site-packages\tf_agents\environments\tf_py_environment.py in _step_py(*flattened_actions)
#     201         packed = tf.nest.pack_sequence_as(
#     202             structure=self.action_spec(), flat_sequence=flattened_actions)
# --> 203         self._time_step = self._env.step(packed)
#     204         return tf.nest.flatten(self._time_step)
#     205
#
# c:\dev\github\easyagents\env\lib\site-packages\tf_agents\environments\py_environment.py in step(self, action)
#     172       return self.reset()
#     173
# --> 174     self._current_time_step = self._step(action)
#     175     return self._current_time_step
#     176
#
# c:\dev\github\easyagents\env\lib\site-packages\tf_agents\environments\batched_py_environment.py in _step(self, actions)
#     128     if self._num_envs == 1:
#     129       actions = nest_utils.unbatch_nested_array(actions)
# --> 130       time_steps = self._envs[0].step(actions)
#     131       return nest_utils.batch_nested_array(time_steps)
#     132     else:
#
# c:\dev\github\easyagents\env\lib\site-packages\tf_agents\environments\py_environment.py in step(self, action)
#     172       return self.reset()
#     173
# --> 174     self._current_time_step = self._step(action)
#     175     return self._current_time_step
#     176
#
# c:\dev\github\easyagents\env\lib\site-packages\tf_agents\environments\wrappers.py in _step(self, action)
#      99       return self.reset()
#     100
# --> 101     time_step = self._env.step(action)
#     102
#     103     self._num_steps += 1
#
# c:\dev\github\easyagents\env\lib\site-packages\tf_agents\environments\py_environment.py in step(self, action)
#     172       return self.reset()
#     173
# --> 174     self._current_time_step = self._step(action)
#     175     return self._current_time_step
#     176
#
# c:\dev\github\easyagents\env\lib\site-packages\tf_agents\environments\gym_wrapper.py in _step(self, action)
#     176     # agents and if we can pass them through directly to gym.
#     177
# --> 178     observation, reward, self._done, self._info = self._gym_env.step(action)
#     179
#     180     if self._match_obs_space_dtype:
#
# C:\Dev\GitHub\easyagents\easyagents\backends\monitor.py in step(self, action)
#     175
#     176         if self._backend_agent:
# --> 177             self._backend_agent._on_gym_step_end(self, action, result)
#     178         return result
#     179
#
# C:\Dev\GitHub\easyagents\easyagents\backends\core.py in _on_gym_step_end(self, env, action, step_result)
#     156         ac.gym.gym_env = env.env
#     157         if ac.is_play or ac.is_eval:
# --> 158             self._on_play_step_end(action, step_result)
#     159         if ac.is_train:
#     160             self._on_train_step_end(action, step_result)
#
# C:\Dev\GitHub\easyagents\easyagents\backends\core.py in _on_play_step_end(self, action, step_result)
#     226         pc.sum_of_rewards[pc.episodes_done + 1] += reward
#     227         for c in self._callbacks:
# --> 228             c.on_play_step_end(self._agent_context, action, step_result)
#     229
#     230     def _on_train_begin(self):
#
# C:\Dev\GitHub\easyagents\easyagents\callbacks\plot.py in on_play_step_end(self, agent_context, action, step_result)
#     105     def on_play_step_end(self, agent_context: core.AgentContext, action, step_result: Tuple):
#     106         if agent_context.is_plot(core.PlotType.PLAY_STEP):
# --> 107             self._display(agent_context, delayed=True)
#     108
#     109     def on_play_end(self, agent_context: core.AgentContext):
#
# C:\Dev\GitHub\easyagents\easyagents\callbacks\plot.py in _display(self, agent_context, delayed)
#      93                     if self._call_jupyter_display:
#      94                         # noinspection PyTypeChecker
# ---> 95                         display(pyc.figure)
#      96                     self._last_jupyter_display = time.time()
#      97                     self._call_jupyter_display = True
#
# c:\dev\github\easyagents\env\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# c:\dev\github\easyagents\env\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <c:\dev\github\easyagents\env\lib\site-packages\decorator.py:decorator-gen-9> in __call__(self, obj)
#
# c:\dev\github\easyagents\env\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# c:\dev\github\easyagents\env\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\dev\github\easyagents\env\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# c:\dev\github\easyagents\env\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# c:\dev\github\easyagents\env\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2059                     bbox_inches = self.figure.get_tightbbox(renderer,
# -> 2060                             bbox_extra_artists=bbox_artists)
#    2061                     pad = kwargs.pop("pad_inches", None)
#    2062                     if pad is None:
#
# c:\dev\github\easyagents\env\lib\site-packages\matplotlib\figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2365
#    2366         for a in artists:
# -> 2367             bbox = a.get_tightbbox(renderer)
#    2368             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2369                 bb.append(bbox)
#
# c:\dev\github\easyagents\env\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4353
#    4354         if self.axison:
# -> 4355             bb_xaxis = self.xaxis.get_tightbbox(renderer)
#    4356             if bb_xaxis:
#    4357                 bb.append(bb_xaxis)
#
# c:\dev\github\easyagents\env\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer)
#    1162         ticks_to_draw = self._update_ticks()
#    1163
# -> 1164         self._update_label_position(renderer)
#    1165
#    1166         # go back to just this axis's tick labels
#
# c:\dev\github\easyagents\env\lib\site-packages\matplotlib\axis.py in _update_label_position(self, renderer)
#    2023                 # use axes if spine doesn't exist
#    2024                 spinebbox = self.axes.bbox
# -> 2025             bbox = mtransforms.Bbox.union(bboxes + [spinebbox])
#    2026             bottom = bbox.y0
#    2027
#
# c:\dev\github\easyagents\env\lib\site-packages\matplotlib\transforms.py in union(bboxes)
#     702         x0 = np.min([bbox.xmin for bbox in bboxes])
#     703         x1 = np.max([bbox.xmax for bbox in bboxes])
# --> 704         y0 = np.min([bbox.ymin for bbox in bboxes])
#     705         y1 = np.max([bbox.ymax for bbox in bboxes])
#     706         return Bbox([[x0, y0], [x1, y1]])
#
# c:\dev\github\easyagents\env\lib\site-packages\matplotlib\transforms.py in <listcomp>(.0)
#     702         x0 = np.min([bbox.xmin for bbox in bboxes])
#     703         x1 = np.max([bbox.xmax for bbox in bboxes])
# --> 704         y0 = np.min([bbox.ymin for bbox in bboxes])
#     705         y1 = np.max([bbox.ymax for bbox in bboxes])
#     706         return Bbox([[x0, y0], [x1, y1]])
#
# c:\dev\github\easyagents\env\lib\site-packages\matplotlib\transforms.py in ymin(self)
#     353     def ymin(self):
#     354         """The bottom edge of the bounding box."""
# --> 355         return np.min(self.get_points()[:, 1])
#     356
#     357     @property
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# c:\dev\github\easyagents\env\lib\site-packages\numpy\core\fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2744     """
#    2745     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
# -> 2746                           keepdims=keepdims, initial=initial, where=where)
#    2747
#    2748
#
# c:\dev\github\easyagents\env\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      88                 return reduction(axis=axis, out=out, **passkwargs)
#      89
# ---> 90     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      91
#      92
#
# KeyboardInterrupt:
