# %%
import easyagents 
from easyagents.callbacks.duration import Fast, SingleEpisode
from easyagents.callbacks.log import LogIteration, LogStep, LogAgent, LogCallbacks, LogAgentContext
from easyagents.callbacks.plot import PlotLoss, PlotSteps, PlotRewards, PlotState, ToMovie
# Out:
# c:\dev\github\easyagents\env\lib\site-packages\gym\logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# WARNING: Logging before flag parsing goes to stderr.
# W0907 10:08:02.634185  4104 __init__.py:689]
#
#   TensorFlow's `tf-nightly` package will soon be updated to TensorFlow 2.0.
#
#   Please upgrade your code to TensorFlow 2.0:
#     * https://www.tensorflow.org/beta/guide/migration_guide
#
#   Or install the latest stable TensorFlow 1.X release:
#     * `pip install -U "tensorflow==1.*"`
#
#   Otherwise your code may be broken by the change.

# %%
agent = easyagents.PpoAgent("CartPole-v0")
agent.train([Fast(),PlotRewards(),PlotSteps(),PlotLoss(), PlotState(), ToMovie(fps=2)])
# Out:
#             <video width="640" height="480" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4">
#             Your browser does not support the video tag.
#             </video>

# %%
agent.play([PlotState(),PlotRewards()], num_episodes=10)

# %%
agent=easyagents.PpoAgent("CartPole-v0")
agent.train([Fast(),PlotLoss(),PlotRewards()])

# %%
agent.play(PlotState())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-55c15d5568ce> in <module>
# ----> 1 agent.play(PlotState())
#
# C:\Dev\GitHub\easyagents\easyagents\agents.py in play(self, callbacks, num_episodes, max_steps_per_episode, play_context)
#     161             play_context.max_steps_per_episode = max_steps_per_episode
#     162             play_context.num_episodes = num_episodes
# --> 163         super().play(play_context=play_context, callbacks=callbacks)
#     164
#     165     def train(self,
#
# C:\Dev\GitHub\easyagents\easyagents\agents.py in play(self, play_context, callbacks)
#      96             callbacks = [callbacks]
#      97         callbacks = self._prepare_callbacks(callbacks)
# ---> 98         self._backend_agent.play(play_context=play_context, callbacks=callbacks)
#      99
# ...

# %%
agent=easyagents.PpoAgent("CartPole-v0")
agent.train([Fast(), PlotState()])
