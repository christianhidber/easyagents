# %% [markdown]
# # CartPole Gym environment with TfAgents

# %% [markdown]
# ## Install packages (gym, tfagents, tensorflow,....)

# %%
# !pip install easyagents >/dev/null

# %% [markdown]
# ##### suppress package warnings, prepare matlab, if in colab: load additional packages for rendering

# %%
import sys
import warnings
import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')
if 'google.colab' in sys.modules:
    # !apt-get install xvfb >/dev/null
    # !pip install pyvirtualdisplay >/dev/null    
    
    from pyvirtualdisplay import Display
    Display(visible=0, size=(960, 720)).start()

# %% [markdown]
# ## Dry Run (very short training)

# %%
from easyagents.tfagents import DqnAgent
from easyagents.tfagents import PpoAgent
from easyagents.config import TrainingFast
from easyagents.config import LoggingVerbose

ppoAgent = DqnAgent( gym_env_name='CartPole-v0', training=TrainingFast(), logging=LoggingVerbose())
ppoAgent.train()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# I0730 17:16:34.010347 18300 agents.py:115] DqnAgent on CartPole-v0 [fc_layers=(75, 75), learning_rate=0.001]
# I0730 17:16:34.018349 18300 agents.py:115] Training 9=3*3 episodes [max 500 steps/episode, 1 epochs/iteration, policy eval every 3=1*3 episodes]
# I0730 17:16:34.018865 18300 agents.py:110] executing: tf.compat.v1.enable_v2_behavior()
# I0730 17:16:34.019878 18300 agents.py:110] executing: tf.enable_eager_execution()
# I0730 17:16:34.021878 18300 agents.py:110] executing: tf.compat.v1.set_random_seed(0)
# I0730 17:16:34.021878 18300 agents.py:110] Creating environment:
# I0730 17:16:34.022912 18300 agents.py:110]    executing tf_py_environment.TFPyEnvironment( suite_gym.load )
# I0730 17:16:34.061270 18300 agents.py:110] Creating agent:
# I0730 17:16:34.063265 18300 agents.py:110]   creating  tf.compat.v1.train.AdamOptimizer( ... )
# I0730 17:16:34.064262 18300 agents.py:110]   creating  QNetwork( ... )
# I0730 17:16:34.076311 18300 agents.py:110]   creating  DqnAgent( ... )
# I0730 17:16:34.097362 18300 agents.py:110]   executing tf_agent.initialize()
# I0730 17:16:34.150716 18300 agents.py:110] Creating data collection:
# W0730 17:16:35.002594 18300 module_wrapper.py:126] From c:\dev\github\easyagents\env\lib\site-packages\tensorflow_core\python\util\module_wrapper.py:153: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
#
# I0730 17:16:36.236326 18300 easyenv.py:83] #EnvId ResetCount.Steps [R=sumRewards]
# I0730 17:16:36.238304 18300 easyenv.py:86] #0   0.0   [totalReward=   0.0] executing reset(...)
# I0730 17:16:36.244026 18300 easyenv.py:86] #0   1.1   [totalReward=   1.0] executing step( 0 ) = ( reward=1.0, state=[-0.04552503 -0.24293761 -0.02969582  0.23371698], done=False, info={} )
# I0730 17:16:36.250662 18300 easyenv.py:86] #0   1.2   [totalReward=   2.0] executing step( 1 ) = ( reward=1.0, state=[-0.05038378 -0.04740422 -0.02502148 -0.06818308], done=False, info={} )
# I0730 17:16:36.260303 18300 easyenv.py:86] #0   1.3   [totalReward=   3.0] executing step( 1 ) = ( reward=1.0, state=[-0.05133186  0.14806736 -0.02638514 -0.36865421], done=False, info={} )
# I0730 17:16:36.268316 18300 easyenv.py:86] #0   1.4   [totalReward=   4.0] executing step( 0 ) = ( reward=1.0, state=[-0.04837052 -0.04666995 -0.03375822 -0.08440626], done=False, info={} )
# I0730 17:16:36.275303 18300 easyenv.py:86] #0   1.5   [totalReward=   5.0] executing step( 1 ) = ( reward=1.0, state=[-0.04930391  0.14891924 -0.03544635 -0.38754592], done=False, info={} )
# I0730 17:16:36.285333 18300 easyenv.py:86] #0   1.6   [totalReward=   6.0] executing step( 0 ) = ( reward=1.0, state=[-0.04632553 -0.04568209 -0.04319727 -0.10624632], done=False, info={} )
# I0730 17:16:36.294308 18300 easyenv.py:86] #0   1.7   [totalReward=   7.0] executing step( 1 ) = ( reward=1.0, state=[-0.04723917  0.15003142 -0.04532219 -0.41223877], done=False, info={} )
# I0730 17:16:36.301312 18300 easyenv.py:86] #0   1.8   [totalReward=   8.0] executing step( 1 ) = ( reward=1.0, state=[-0.04423854  0.34576556 -0.05356697 -0.71885865], done=False, info={} )
# I0730 17:16:36.309307 18300 easyenv.py:86] #0   1.9   [totalReward=   9.0] executing step( 1 ) = ( reward=1.0, state=[-0.03732323  0.5415862  -0.06794414 -1.02790946], done=False, info={} )
# I0730 17:16:36.318377 18300 easyenv.py:86] #0   1.10  [totalReward=  10.0] executing step( 0 ) = ( reward=1.0, state=[-0.02649151  0.34743117 -0.08850233 -0.75730909], done=False, info={} )
# I0730 17:16:36.325325 18300 easyenv.py:86] #0   1.11  [totalReward=  11.0] executing step( 1 ) = ( reward=1.0, state=[-0.01954289  0.54365413 -0.10364851 -1.07647731], done=False, info={} )
# I0730 17:16:36.336226 18300 easyenv.py:86] #0   1.12  [totalReward=  12.0] executing step( 0 ) = ( reward=1.0, state=[-0.0086698   0.35004271 -0.12517806 -0.81803689], done=False, info={} )
# I0730 17:16:36.343313 18300 easyenv.py:86] #0   1.13  [totalReward=  13.0] executing step( 0 ) = ( reward=1.0, state=[-0.00166895  0.15683616 -0.1415388  -0.567201  ], done=False, info={} )
# I0730 17:16:36.350359 18300 easyenv.py:86] #0   1.14  [totalReward=  14.0] executing step( 1 ) = ( reward=1.0, state=[ 0.00146777  0.35363015 -0.15288282 -0.90091372], done=False, info={} )
# I0730 17:16:36.358429 18300 easyenv.py:86] #0   1.15  [totalReward=  15.0] executing step( 1 ) = ( reward=1.0, state=[ 0.00854038  0.55045607 -0.17090109 -1.23748164], done=False, info={} )
# I0730 17:16:36.366566 18300 easyenv.py:86] #0   1.16  [totalReward=  16.0] executing step( 0 ) = ( reward=1.0, state=[ 0.0195495   0.3578911  -0.19565072 -1.00284283], done=False, info={} )
# I0730 17:16:36.375439 18300 easyenv.py:86] #0   1.17  [totalReward=  17.0] executing step( 1 ) = ( reward=1.0, state=[ 0.02670732  0.55501206 -0.21570758 -1.3500381 ], done=True, info={} )
# I0730 17:16:36.376425 18300 easyenv.py:86] #0   1.17  [totalReward=  17.0] game over
# I0730 17:16:36.383423 18300 easyenv.py:86] #0   1.17  [totalReward=  17.0] executing reset(...)
# I0730 17:16:36.391457 18300 easyenv.py:86] #0   2.1   [totalReward=   1.0] executing step( 1 ) = ( reward=1.0, state=[-0.03086404  0.19657901 -0.03899554 -0.3295558 ], done=False, info={} )
# I0730 17:16:36.400579 18300 easyenv.py:86] #0   2.2   [totalReward=   2.0] executing step( 0 ) = ( reward=1.0, state=[-0.02693246  0.00203325 -0.04558665 -0.04942079], done=False, info={} )
# I0730 17:16:36.406440 18300 easyenv.py:86] #0   2.3   [totalReward=   3.0] executing step( 0 ) = ( reward=1.0, state=[-0.02689179 -0.19240639 -0.04657507  0.22853783], done=False, info={} )
# I0730 17:16:36.414440 18300 easyenv.py:86] #0   2.4   [totalReward=   4.0] executing step( 0 ) = ( reward=1.0, state=[-0.03073992 -0.38683289 -0.04200431  0.5061732 ], done=False, info={} )
# I0730 17:16:36.423421 18300 easyenv.py:86] #0   2.5   [totalReward=   5.0] executing step( 1 ) = ( reward=1.0, state=[-0.03847658 -0.19114499 -0.03188085  0.20055462], done=False, info={} )
# I0730 17:16:36.433429 18300 easyenv.py:86] #0   2.6   [totalReward=   6.0] executing step( 1 ) = ( reward=1.0, state=[-0.04229948  0.00441808 -0.02786976 -0.10201231], done=False, info={} )
# I0730 17:16:36.441421 18300 easyenv.py:86] #0   2.7   [totalReward=   7.0] executing step( 1 ) = ( reward=1.0, state=[-0.04221112  0.19992813 -0.02991    -0.40335614], done=False, info={} )
# I0730 17:16:36.448426 18300 easyenv.py:86] #0   2.8   [totalReward=   8.0] executing step( 1 ) = ( reward=1.0, state=[-0.03821255  0.39546123 -0.03797713 -0.70531684], done=False, info={} )
# I0730 17:16:36.457493 18300 easyenv.py:86] #0   2.9   [totalReward=   9.0] executing step( 1 ) = ( reward=1.0, state=[-0.03030333  0.59108825 -0.05208346 -1.00970837], done=False, info={} )
# I0730 17:16:36.465504 18300 easyenv.py:86] #0   2.10  [totalReward=  10.0] executing step( 0 ) = ( reward=1.0, state=[-0.01848156  0.39669867 -0.07227763 -0.73382501], done=False, info={} )
# I0730 17:16:36.477760 18300 easyenv.py:86] #0   2.11  [totalReward=  11.0] executing step( 1 ) = ( reward=1.0, state=[-0.01054759  0.59274083 -0.08695413 -1.04835162], done=False, info={} )
# I0730 17:16:36.485498 18300 easyenv.py:86] #0   2.12  [totalReward=  12.0] executing step( 0 ) = ( reward=1.0, state=[ 0.00130723  0.39887352 -0.10792116 -0.78418165], done=False, info={} )
# I0730 17:16:36.494497 18300 easyenv.py:86] #0   2.13  [totalReward=  13.0] executing step( 1 ) = ( reward=1.0, state=[ 0.0092847   0.59529986 -0.12360479 -1.10877426], done=False, info={} )
# I0730 17:16:36.505104 18300 easyenv.py:86] #0   2.14  [totalReward=  14.0] executing step( 0 ) = ( reward=1.0, state=[ 0.02119069  0.40199971 -0.14578028 -0.8572835 ], done=False, info={} )
# I0730 17:16:36.516487 18300 easyenv.py:86] #0   2.15  [totalReward=  15.0] executing step( 0 ) = ( reward=1.0, state=[ 0.02923069  0.2091326  -0.16292595 -0.61375925], done=False, info={} )
# I0730 17:16:36.525498 18300 easyenv.py:86] #0   2.16  [totalReward=  16.0] executing step( 1 ) = ( reward=1.0, state=[ 0.03341334  0.40611118 -0.17520114 -0.95300281], done=False, info={} )
# I0730 17:16:36.531513 18300 easyenv.py:86] #0   2.17  [totalReward=  17.0] executing step( 0 ) = ( reward=1.0, state=[ 0.04153556  0.21372402 -0.19426119 -0.72008583], done=False, info={} )
# I0730 17:16:36.539490 18300 easyenv.py:86] #0   2.18  [totalReward=  18.0] executing step( 0 ) = ( reward=1.0, state=[ 0.04581004  0.02174432 -0.20866291 -0.49428707], done=False, info={} )
# I0730 17:16:36.550493 18300 easyenv.py:86] #0   2.19  [totalReward=  19.0] executing step( 0 ) = ( reward=1.0, state=[ 0.04624493 -0.16991879 -0.21854865 -0.27393121], done=True, info={} )
# I0730 17:16:36.553489 18300 easyenv.py:86] #0   2.19  [totalReward=  19.0] game over
# I0730 17:16:36.565568 18300 easyenv.py:86] #0   2.19  [totalReward=  19.0] executing reset(...)
# I0730 17:16:36.578169 18300 easyenv.py:86] #0   3.1   [totalReward=   1.0] executing step( 0 ) = ( reward=1.0, state=[-0.04001638 -0.19383932  0.04749436  0.27784164], done=False, info={} )
# I0730 17:16:36.591792 18300 easyenv.py:86] #0   3.2   [totalReward=   2.0] executing step( 1 ) = ( reward=1.0, state=[-0.04389316  0.00057403  0.05305119  0.00050855], done=False, info={} )
# I0730 17:16:36.598196 18300 easyenv.py:86] #0   3.3   [totalReward=   3.0] executing step( 1 ) = ( reward=1.0, state=[-0.04388168  0.19489659  0.05306136 -0.27497548], done=False, info={} )
# I0730 17:16:36.606792 18300 easyenv.py:86] #0   3.4   [totalReward=   4.0] executing step( 1 ) = ( reward=1.0, state=[-0.03998375  0.38922291  0.04756185 -0.55046198], done=False, info={} )
# I0730 17:16:36.621844 18300 easyenv.py:86] #0   3.5   [totalReward=   5.0] executing step( 0 ) = ( reward=1.0, state=[-0.03219929  0.19346631  0.03655261 -0.24318123], done=False, info={} )
# I0730 17:16:36.628789 18300 easyenv.py:86] #0   3.6   [totalReward=   6.0] executing step( 1 ) = ( reward=1.0, state=[-0.02832997  0.38804761  0.03168899 -0.52411413], done=False, info={} )
# I0730 17:16:36.633795 18300 easyenv.py:86] #0   3.7   [totalReward=   7.0] executing step( 1 ) = ( reward=1.0, state=[-0.02056901  0.58270959  0.02120671 -0.80664551], done=False, info={} )
# I0730 17:16:36.642795 18300 easyenv.py:86] #0   3.8   [totalReward=   8.0] executing step( 0 ) = ( reward=1.0, state=[-0.00891482  0.38730348  0.0050738  -0.50736795], done=False, info={} )
# I0730 17:16:36.650789 18300 easyenv.py:86] #0   3.9   [totalReward=   9.0] executing step( 1 ) = ( reward=1.0, state=[-0.00116875  0.58235358 -0.00507356 -0.79844764], done=False, info={} )
# I0730 17:16:36.655812 18300 easyenv.py:86] #0   3.10  [totalReward=  10.0] executing step( 1 ) = ( reward=1.0, state=[ 0.01047832  0.77754477 -0.02104251 -1.09272227], done=False, info={} )
# I0730 17:16:36.660915 18300 easyenv.py:86] #0   3.11  [totalReward=  11.0] executing step( 0 ) = ( reward=1.0, state=[ 0.02602921  0.58270631 -0.04289696 -0.80671533], done=False, info={} )
# I0730 17:16:36.664918 18300 easyenv.py:86] #0   3.12  [totalReward=  12.0] executing step( 1 ) = ( reward=1.0, state=[ 0.03768334  0.77838915 -0.05903127 -1.11257741], done=False, info={} )
# I0730 17:16:36.669915 18300 easyenv.py:86] #0   3.13  [totalReward=  13.0] executing step( 1 ) = ( reward=1.0, state=[ 0.05325112  0.97423461 -0.08128281 -1.42317901], done=False, info={} )
# I0730 17:16:36.674915 18300 easyenv.py:86] #0   3.14  [totalReward=  14.0] executing step( 1 ) = ( reward=1.0, state=[ 0.07273582  1.17026215 -0.10974639 -1.74012034], done=False, info={} )
# I0730 17:16:36.678916 18300 easyenv.py:86] #0   3.15  [totalReward=  15.0] executing step( 1 ) = ( reward=1.0, state=[ 0.09614106  1.36644965 -0.1445488  -2.06483189], done=False, info={} )
# I0730 17:16:36.683923 18300 easyenv.py:86] #0   3.16  [totalReward=  16.0] executing step( 1 ) = ( reward=1.0, state=[ 0.12347005  1.56271874 -0.18584544 -2.39851469], done=False, info={} )
# I0730 17:16:36.687948 18300 easyenv.py:86] #0   3.17  [totalReward=  17.0] executing step( 1 ) = ( reward=1.0, state=[ 0.15472443  1.75891781 -0.23381573 -2.74207017], done=True, info={} )
# I0730 17:16:36.688962 18300 easyenv.py:86] #0   3.17  [totalReward=  17.0] game over
# I0730 17:16:36.692915 18300 easyenv.py:86] #0   3.17  [totalReward=  17.0] executing reset(...)
# I0730 17:16:36.697915 18300 easyenv.py:86] #0   4.1   [totalReward=   1.0] executing step( 1 ) = ( reward=1.0, state=[-0.01789379  0.14781974  0.01605527 -0.32577777], done=False, info={} )
# I0730 17:16:36.703915 18300 easyenv.py:86] #0   4.2   [totalReward=   2.0] executing step( 1 ) = ( reward=1.0, state=[-0.01493739  0.34270946  0.00953972 -0.61335463], done=False, info={} )
# I0730 17:16:36.708914 18300 easyenv.py:86] #0   4.3   [totalReward=   3.0] executing step( 0 ) = ( reward=1.0, state=[-0.0080832   0.14745551 -0.00272738 -0.31768239], done=False, info={} )
# I0730 17:16:36.712915 18300 easyenv.py:86] #0   4.4   [totalReward=   4.0] executing step( 1 ) = ( reward=1.0, state=[-0.00513409  0.3426162  -0.00908102 -0.61122418], done=False, info={} )
# I0730 17:16:36.717924 18300 easyenv.py:86] #0   4.5   [totalReward=   5.0] executing step( 0 ) = ( reward=1.0, state=[ 0.00171823  0.14762234 -0.02130551 -0.32141524], done=False, info={} )
# I0730 17:16:36.722916 18300 easyenv.py:86] #0   4.6   [totalReward=   6.0] executing step( 1 ) = ( reward=1.0, state=[ 0.00467068  0.34304112 -0.02773381 -0.62074022], done=False, info={} )
# I0730 17:16:36.728362 18300 easyenv.py:86] #0   4.7   [totalReward=   7.0] executing step( 1 ) = ( reward=1.0, state=[ 0.0115315   0.53853918 -0.04014862 -0.92202725], done=False, info={} )
# I0730 17:16:36.731918 18300 easyenv.py:86] #0   4.8   [totalReward=   8.0] executing step( 1 ) = ( reward=1.0, state=[ 0.02230228  0.73417995 -0.05858916 -1.22705244], done=False, info={} )
# I0730 17:16:36.738240 18300 easyenv.py:86] #0   4.9   [totalReward=   9.0] executing step( 1 ) = ( reward=1.0, state=[ 0.03698588  0.93000509 -0.08313021 -1.5375015 ], done=False, info={} )
# I0730 17:16:36.742916 18300 easyenv.py:86] #0   4.10  [totalReward=  10.0] executing step( 0 ) = ( reward=1.0, state=[ 0.05558598  0.73597625 -0.11388024 -1.27187545], done=False, info={} )
# I0730 17:16:36.746915 18300 easyenv.py:86] #0   4.11  [totalReward=  11.0] executing step( 1 ) = ( reward=1.0, state=[ 0.07030551  0.93235245 -0.13931775 -1.59794021], done=False, info={} )
# I0730 17:16:36.751918 18300 easyenv.py:86] #0   4.12  [totalReward=  12.0] executing step( 0 ) = ( reward=1.0, state=[ 0.08895256  0.73912947 -0.17127655 -1.35174101], done=False, info={} )
# I0730 17:16:36.756916 18300 easyenv.py:86] #0   4.13  [totalReward=  13.0] executing step( 1 ) = ( reward=1.0, state=[ 0.10373515  0.93593785 -0.19831137 -1.69274349], done=False, info={} )
# I0730 17:16:36.761916 18300 easyenv.py:86] #0   4.14  [totalReward=  14.0] executing step( 1 ) = ( reward=1.0, state=[ 0.1224539   1.13272026 -0.23216624 -2.04005405], done=True, info={} )
# I0730 17:16:36.762914 18300 easyenv.py:86] #0   4.14  [totalReward=  14.0] game over
# I0730 17:16:36.767929 18300 easyenv.py:86] #0   4.14  [totalReward=  14.0] executing reset(...)
# I0730 17:16:36.774913 18300 easyenv.py:86] #0   5.1   [totalReward=   1.0] executing step( 1 ) = ( reward=1.0, state=[ 0.04424361  0.18172587  0.00387065 -0.32314722], done=False, info={} )
# I0730 17:16:36.781914 18300 easyenv.py:86] #0   5.2   [totalReward=   2.0] executing step( 0 ) = ( reward=1.0, state=[ 0.04787813 -0.01345099 -0.0025923  -0.02924616], done=False, info={} )
# I0730 17:16:36.787917 18300 easyenv.py:86] #0   5.3   [totalReward=   3.0] executing step( 1 ) = ( reward=1.0, state=[ 0.04760911  0.18170804 -0.00317722 -0.32274586], done=False, info={} )
# I0730 17:16:36.792919 18300 easyenv.py:86] #0   5.4   [totalReward=   4.0] executing step( 1 ) = ( reward=1.0, state=[ 0.05124327  0.37687509 -0.00963214 -0.61642906], done=False, info={} )
# I0730 17:16:36.801058 18300 easyenv.py:86] #0   5.5   [totalReward=   5.0] executing step( 1 ) = ( reward=1.0, state=[ 0.05878077  0.57213028 -0.02196072 -0.91213005], done=False, info={} )
# I0730 17:16:36.805918 18300 easyenv.py:86] #0   5.6   [totalReward=   6.0] executing step( 0 ) = ( reward=1.0, state=[ 0.07022338  0.37731222 -0.04020332 -0.62642937], done=False, info={} )
# I0730 17:16:36.811914 18300 easyenv.py:86] #0   5.7   [totalReward=   7.0] executing step( 1 ) = ( reward=1.0, state=[ 0.07776962  0.57297161 -0.05273191 -0.9314979 ], done=False, info={} )
# I0730 17:16:36.819042 18300 easyenv.py:86] #0   5.8   [totalReward=   8.0] executing step( 1 ) = ( reward=1.0, state=[ 0.08922906  0.768764   -0.07136187 -1.24027424], done=False, info={} )
# I0730 17:16:36.826916 18300 easyenv.py:86] #0   5.9   [totalReward=   9.0] executing step( 0 ) = ( reward=1.0, state=[ 0.10460434  0.57462722 -0.09616735 -0.97077283], done=False, info={} )
# I0730 17:16:36.834916 18300 easyenv.py:86] #0   5.10  [totalReward=  10.0] executing step( 0 ) = ( reward=1.0, state=[ 0.11609688  0.38091836 -0.11558281 -0.70978173], done=False, info={} )
# I0730 17:16:36.840913 18300 easyenv.py:86] #0   5.11  [totalReward=  11.0] executing step( 0 ) = ( reward=1.0, state=[ 0.12371525  0.18757079 -0.12977844 -0.45560121], done=False, info={} )
# I0730 17:16:36.846348 18300 easyenv.py:86] #0   5.12  [totalReward=  12.0] executing step( 0 ) = ( reward=1.0, state=[ 0.12746666 -0.00550038 -0.13889047 -0.20647772], done=False, info={} )
# I0730 17:16:36.851917 18300 easyenv.py:86] #0   5.13  [totalReward=  13.0] executing step( 1 ) = ( reward=1.0, state=[ 0.12735666  0.19130617 -0.14302002 -0.53954739], done=False, info={} )
# I0730 17:16:36.857455 18300 easyenv.py:86] #0   5.14  [totalReward=  14.0] executing step( 1 ) = ( reward=1.0, state=[ 0.13118278  0.38811834 -0.15381097 -0.87365616], done=False, info={} )
# I0730 17:16:36.862349 18300 easyenv.py:86] #0   5.15  [totalReward=  15.0] executing step( 0 ) = ( reward=1.0, state=[ 0.13894515  0.19538456 -0.17128409 -0.63301084], done=False, info={} )
# I0730 17:16:36.868348 18300 easyenv.py:86] #0   5.16  [totalReward=  16.0] executing step( 0 ) = ( reward=1.0, state=[ 0.14285284  0.00301362 -0.18394431 -0.3987886 ], done=False, info={} )
# I0730 17:16:36.873486 18300 easyenv.py:86] #0   5.17  [totalReward=  17.0] executing step( 0 ) = ( reward=1.0, state=[ 0.14291311 -0.18908753 -0.19192008 -0.16927321], done=False, info={} )
# I0730 17:16:36.879381 18300 easyenv.py:86] #0   5.18  [totalReward=  18.0] executing step( 1 ) = ( reward=1.0, state=[ 0.13913136  0.00818923 -0.19530554 -0.51583403], done=False, info={} )
# I0730 17:16:36.885347 18300 easyenv.py:86] #0   5.19  [totalReward=  19.0] executing step( 0 ) = ( reward=1.0, state=[ 0.13929514 -0.18372396 -0.20562223 -0.2904926 ], done=False, info={} )
# I0730 17:16:36.890349 18300 easyenv.py:86] #0   5.20  [totalReward=  20.0] executing step( 0 ) = ( reward=1.0, state=[ 0.13562066 -0.37541151 -0.21143208 -0.06904621], done=True, info={} )
# I0730 17:16:36.891344 18300 easyenv.py:86] #0   5.20  [totalReward=  20.0] game over
# I0730 17:16:36.896630 18300 easyenv.py:86] #0   5.20  [totalReward=  20.0] executing reset(...)
# I0730 17:16:36.901348 18300 easyenv.py:86] #0   6.1   [totalReward=   1.0] executing step( 1 ) = ( reward=1.0, state=[ 0.02829381  0.17015863 -0.0041539  -0.27530025], done=False, info={} )
# I0730 17:16:36.906424 18300 easyenv.py:86] #0   6.2   [totalReward=   2.0] executing step( 0 ) = ( reward=1.0, state=[ 0.03169698 -0.02490381 -0.00965991  0.01606964], done=False, info={} )
# I0730 17:16:36.911348 18300 easyenv.py:86] #0   6.3   [totalReward=   3.0] executing step( 0 ) = ( reward=1.0, state=[ 0.03119891 -0.2198859  -0.00933851  0.30568917], done=False, info={} )
# I0730 17:16:36.915354 18300 easyenv.py:86] #0   6.4   [totalReward=   4.0] executing step( 1 ) = ( reward=1.0, state=[ 0.02680119 -0.02463212 -0.00322473  0.01007579], done=False, info={} )
# I0730 17:16:36.921348 18300 easyenv.py:86] #0   6.5   [totalReward=   5.0] executing step( 1 ) = ( reward=1.0, state=[ 0.02630855  0.17053592 -0.00302321 -0.28362283], done=False, info={} )
# I0730 17:16:36.925348 18300 easyenv.py:86] #0   6.6   [totalReward=   6.0] executing step( 0 ) = ( reward=1.0, state=[ 0.02971926 -0.02454278 -0.00869567  0.00810506], done=False, info={} )
# I0730 17:16:36.929350 18300 easyenv.py:86] #0   6.7   [totalReward=   7.0] executing step( 0 ) = ( reward=1.0, state=[ 0.02922841 -0.21953895 -0.00853357  0.29803176], done=False, info={} )
# I0730 17:16:36.934383 18300 easyenv.py:86] #0   6.8   [totalReward=   8.0] executing step( 0 ) = ( reward=1.0, state=[ 0.02483763 -0.41453822 -0.00257294  0.58801118], done=False, info={} )
# I0730 17:16:36.940349 18300 easyenv.py:86] #0   6.9   [totalReward=   9.0] executing step( 0 ) = ( reward=1.0, state=[ 0.01654686 -0.60962405  0.00918729  0.87988251], done=False, info={} )
# I0730 17:16:36.946349 18300 easyenv.py:86] #0   6.10  [totalReward=  10.0] executing step( 1 ) = ( reward=1.0, state=[ 0.00435438 -0.41462811  0.02678494  0.59010198], done=False, info={} )
# I0730 17:16:36.951364 18300 easyenv.py:86] #0   6.11  [totalReward=  11.0] executing step( 1 ) = ( reward=1.0, state=[-0.00393818 -0.21989123  0.03858698  0.30597527], done=False, info={} )
# I0730 17:16:36.957557 18300 easyenv.py:86] #0   6.12  [totalReward=  12.0] executing step( 1 ) = ( reward=1.0, state=[-0.008336   -0.02533979  0.04470648  0.02570709], done=False, info={} )
# I0730 17:16:36.962069 18300 easyenv.py:86] #0   6.13  [totalReward=  13.0] executing step( 0 ) = ( reward=1.0, state=[-0.0088428  -0.22107341  0.04522063  0.33215349], done=False, info={} )
# I0730 17:16:36.966064 18300 easyenv.py:86] #0   6.14  [totalReward=  14.0] executing step( 1 ) = ( reward=1.0, state=[-0.01326427 -0.02662331  0.0518637   0.05406685], done=False, info={} )
# I0730 17:16:36.973068 18300 easyenv.py:86] #0   6.15  [totalReward=  15.0] executing step( 0 ) = ( reward=1.0, state=[-0.01379673 -0.22244908  0.05294503  0.36265163], done=False, info={} )
# I0730 17:16:36.977068 18300 easyenv.py:86] #0   6.16  [totalReward=  16.0] executing step( 0 ) = ( reward=1.0, state=[-0.01824571 -0.418282    0.06019807  0.67154796], done=False, info={} )
# I0730 17:16:36.982064 18300 easyenv.py:86] #0   6.17  [totalReward=  17.0] executing step( 0 ) = ( reward=1.0, state=[-0.02661135 -0.61418684  0.07362902  0.98256049], done=False, info={} )
# I0730 17:16:36.986433 18300 easyenv.py:86] #0   6.18  [totalReward=  18.0] executing step( 1 ) = ( reward=1.0, state=[-0.03889509 -0.42012458  0.09328023  0.71388316], done=False, info={} )
# I0730 17:16:36.991066 18300 easyenv.py:86] #0   6.19  [totalReward=  19.0] executing step( 0 ) = ( reward=1.0, state=[-0.04729758 -0.61640564  0.1075579   1.03440941], done=False, info={} )
# I0730 17:16:36.995071 18300 easyenv.py:86] #0   6.20  [totalReward=  20.0] executing step( 1 ) = ( reward=1.0, state=[-0.0596257  -0.4228655   0.12824609  0.77733791], done=False, info={} )
# I0730 17:16:36.998066 18300 easyenv.py:86] #0   6.21  [totalReward=  21.0] executing step( 0 ) = ( reward=1.0, state=[-0.06808301 -0.61949585  0.14379284  1.10746235], done=False, info={} )
# I0730 17:16:37.004079 18300 easyenv.py:86] #0   6.22  [totalReward=  22.0] executing step( 1 ) = ( reward=1.0, state=[-0.08047292 -0.42652626  0.16594209  0.86312481], done=False, info={} )
# I0730 17:16:37.009067 18300 easyenv.py:86] #0   6.23  [totalReward=  23.0] executing step( 1 ) = ( reward=1.0, state=[-0.08900345 -0.23400502  0.18320459  0.62687327], done=False, info={} )
# I0730 17:16:37.013065 18300 easyenv.py:86] #0   6.24  [totalReward=  24.0] executing step( 0 ) = ( reward=1.0, state=[-0.09368355 -0.43114738  0.19574205  0.97119937], done=False, info={} )
# I0730 17:16:37.018260 18300 easyenv.py:86] #0   6.25  [totalReward=  25.0] executing step( 0 ) = ( reward=1.0, state=[-0.1023065  -0.62828077  0.21516604  1.31843404], done=True, info={} )
# I0730 17:16:37.019936 18300 easyenv.py:86] #0   6.25  [totalReward=  25.0] game over
# I0730 17:16:37.024945 18300 easyenv.py:86] #0   6.25  [totalReward=  25.0] executing reset(...)
# I0730 17:16:37.028948 18300 easyenv.py:86] #0   7.1   [totalReward=   1.0] executing step( 0 ) = ( reward=1.0, state=[ 0.04276733 -0.22350273 -0.00041713  0.33817638], done=False, info={} )
# I0730 17:16:37.033945 18300 easyenv.py:86] #0   7.2   [totalReward=   2.0] executing step( 1 ) = ( reward=1.0, state=[ 0.03829728 -0.02837485  0.0063464   0.04536194], done=False, info={} )
# I0730 17:16:37.040947 18300 easyenv.py:86] #0   7.3   [totalReward=   3.0] executing step( 0 ) = ( reward=1.0, state=[ 0.03772978 -0.22358722  0.00725364  0.34004044], done=False, info={} )
# I0730 17:16:37.045950 18300 easyenv.py:86] #0   7.4   [totalReward=   4.0] executing step( 1 ) = ( reward=1.0, state=[ 0.03325804 -0.02856923  0.01405445  0.0496537 ], done=False, info={} )
# I0730 17:16:37.055541 18300 easyenv.py:86] #0   7.5   [totalReward=   5.0] executing step( 1 ) = ( reward=1.0, state=[ 0.03268665  0.1663484   0.01504752 -0.23856201], done=False, info={} )
# I0730 17:16:37.062045 18300 easyenv.py:86] #0   7.6   [totalReward=   6.0] executing step( 0 ) = ( reward=1.0, state=[ 0.03601362 -0.02898525  0.01027628  0.0588291 ], done=False, info={} )
# I0730 17:16:37.067309 18300 easyenv.py:86] #0   7.7   [totalReward=   7.0] executing step( 1 ) = ( reward=1.0, state=[ 0.03543391  0.16598787  0.01145286 -0.23059395], done=False, info={} )
# I0730 17:16:37.074048 18300 easyenv.py:86] #0   7.8   [totalReward=   8.0] executing step( 0 ) = ( reward=1.0, state=[ 0.03875367 -0.02929585  0.00684098  0.06567948], done=False, info={} )
# I0730 17:16:37.079374 18300 easyenv.py:86] #0   7.9   [totalReward=   9.0] executing step( 0 ) = ( reward=1.0, state=[ 0.03816776 -0.22451521  0.00815457  0.3605129 ], done=False, info={} )
# I0730 17:16:37.084071 18300 easyenv.py:86] #0   7.10  [totalReward=  10.0] executing step( 1 ) = ( reward=1.0, state=[ 0.03367745 -0.02951012  0.01536483  0.07041241], done=False, info={} )
# I0730 17:16:37.090045 18300 easyenv.py:86] #0   7.11  [totalReward=  11.0] executing step( 1 ) = ( reward=1.0, state=[ 0.03308725  0.16538822  0.01677308 -0.21738351], done=False, info={} )
# I0730 17:16:37.095045 18300 easyenv.py:86] #0   7.12  [totalReward=  12.0] executing step( 0 ) = ( reward=1.0, state=[ 0.03639501 -0.02996944  0.01242541  0.08054282], done=False, info={} )
# I0730 17:16:37.099045 18300 easyenv.py:86] #0   7.13  [totalReward=  13.0] executing step( 0 ) = ( reward=1.0, state=[ 0.03579562 -0.22526729  0.01403626  0.37711995], done=False, info={} )
# I0730 17:16:37.105141 18300 easyenv.py:86] #0   7.14  [totalReward=  14.0] executing step( 0 ) = ( reward=1.0, state=[ 0.03129028 -0.42058575  0.02157866  0.67419531], done=False, info={} )
# I0730 17:16:37.109837 18300 easyenv.py:86] #0   7.15  [totalReward=  15.0] executing step( 1 ) = ( reward=1.0, state=[ 0.02287856 -0.22577024  0.03506257  0.38838371], done=False, info={} )
# I0730 17:16:37.114835 18300 easyenv.py:86] #0   7.16  [totalReward=  16.0] executing step( 0 ) = ( reward=1.0, state=[ 0.01836316 -0.42137188  0.04283024  0.69191212], done=False, info={} )
# I0730 17:16:37.119836 18300 easyenv.py:86] #0   7.17  [totalReward=  17.0] executing step( 1 ) = ( reward=1.0, state=[ 0.00993572 -0.22686952  0.05666849  0.41301438], done=False, info={} )
# I0730 17:16:37.124835 18300 easyenv.py:86] #0   7.18  [totalReward=  18.0] executing step( 1 ) = ( reward=1.0, state=[ 0.00539833 -0.03259472  0.06492877  0.13872158], done=False, info={} )
# I0730 17:16:37.128891 18300 easyenv.py:86] #0   7.19  [totalReward=  19.0] executing step( 1 ) = ( reward=1.0, state=[ 0.00474644  0.16154009  0.06770321 -0.13279139], done=False, info={} )
# I0730 17:16:37.134849 18300 easyenv.py:86] #0   7.20  [totalReward=  20.0] executing step( 0 ) = ( reward=1.0, state=[ 0.00797724 -0.03448305  0.06504738  0.18045923], done=False, info={} )
# I0730 17:16:37.139835 18300 easyenv.py:86] #0   7.21  [totalReward=  21.0] executing step( 1 ) = ( reward=1.0, state=[ 0.00728758  0.1596507   0.06865656 -0.09101511], done=False, info={} )
# I0730 17:16:37.143837 18300 easyenv.py:86] #0   7.22  [totalReward=  22.0] executing step( 0 ) = ( reward=1.0, state=[ 0.01048059 -0.03638473  0.06683626  0.22251445], done=False, info={} )
# I0730 17:16:37.147835 18300 easyenv.py:86] #0   7.23  [totalReward=  23.0] executing step( 1 ) = ( reward=1.0, state=[ 0.0097529   0.15772142  0.07128655 -0.04835947], done=False, info={} )
# I0730 17:16:37.153838 18300 easyenv.py:86] #0   7.24  [totalReward=  24.0] executing step( 1 ) = ( reward=1.0, state=[ 0.01290732  0.35175261  0.07031936 -0.31772656], done=False, info={} )
# I0730 17:16:37.160154 18300 easyenv.py:86] #0   7.25  [totalReward=  25.0] executing step( 0 ) = ( reward=1.0, state=[ 0.01994238  0.15570324  0.06396483 -0.00372241], done=False, info={} )
# I0730 17:16:37.166153 18300 easyenv.py:86] #0   7.26  [totalReward=  26.0] executing step( 1 ) = ( reward=1.0, state=[ 0.02305644  0.3498523   0.06389038 -0.27555759], done=False, info={} )
# I0730 17:16:37.172729 18300 easyenv.py:86] #0   7.27  [totalReward=  27.0] executing step( 0 ) = ( reward=1.0, state=[0.03005349 0.15387974 0.05837923 0.03657248], done=False, info={} )
# I0730 17:16:37.178726 18300 easyenv.py:86] #0   7.28  [totalReward=  28.0] executing step( 0 ) = ( reward=1.0, state=[ 0.03313108 -0.04202868  0.05911068  0.34708824], done=False, info={} )
# I0730 17:16:37.184453 18300 easyenv.py:86] #0   7.29  [totalReward=  29.0] executing step( 1 ) = ( reward=1.0, state=[0.03229051 0.15220485 0.06605244 0.07361521], done=False, info={} )
# I0730 17:16:37.190246 18300 easyenv.py:86] #0   7.30  [totalReward=  30.0] executing step( 1 ) = ( reward=1.0, state=[ 0.03533461  0.34632074  0.06752475 -0.19751837], done=False, info={} )
# I0730 17:16:37.194203 18300 easyenv.py:86] #0   7.31  [totalReward=  31.0] executing step( 0 ) = ( reward=1.0, state=[0.04226102 0.15030119 0.06357438 0.11567808], done=False, info={} )
# I0730 17:16:37.200517 18300 easyenv.py:86] #0   7.32  [totalReward=  32.0] executing step( 0 ) = ( reward=1.0, state=[ 0.04526704 -0.04567135  0.06588794  0.42772132], done=False, info={} )
# I0730 17:16:37.206023 18300 easyenv.py:86] #0   7.33  [totalReward=  33.0] executing step( 1 ) = ( reward=1.0, state=[0.04435362 0.14845858 0.07444237 0.15651531], done=False, info={} )
# I0730 17:16:37.211032 18300 easyenv.py:86] #0   7.34  [totalReward=  34.0] executing step( 1 ) = ( reward=1.0, state=[ 0.04732279  0.34244013  0.07757267 -0.1117853 ], done=False, info={} )
# I0730 17:16:37.215023 18300 easyenv.py:86] #0   7.35  [totalReward=  35.0] executing step( 0 ) = ( reward=1.0, state=[0.05417159 0.14629726 0.07533697 0.20432772], done=False, info={} )
# I0730 17:16:37.220023 18300 easyenv.py:86] #0   7.36  [totalReward=  36.0] executing step( 1 ) = ( reward=1.0, state=[ 0.05709754  0.34026552  0.07942352 -0.06367126], done=False, info={} )
# I0730 17:16:37.224024 18300 easyenv.py:86] #0   7.37  [totalReward=  37.0] executing step( 1 ) = ( reward=1.0, state=[ 0.06390285  0.53416421  0.0781501  -0.33027645], done=False, info={} )
# I0730 17:16:37.229041 18300 easyenv.py:86] #0   7.38  [totalReward=  38.0] executing step( 1 ) = ( reward=1.0, state=[ 0.07458613  0.72809175  0.07154457 -0.59732717], done=False, info={} )
# I0730 17:16:37.233012 18300 easyenv.py:86] #0   7.39  [totalReward=  39.0] executing step( 0 ) = ( reward=1.0, state=[ 0.08914797  0.53204543  0.05959802 -0.28299382], done=False, info={} )
# I0730 17:16:37.241008 18300 easyenv.py:86] #0   7.40  [totalReward=  40.0] executing step( 0 ) = ( reward=1.0, state=[0.09978887 0.33612629 0.05393815 0.02787458], done=False, info={} )
# I0730 17:16:37.245009 18300 easyenv.py:86] #0   7.41  [totalReward=  41.0] executing step( 0 ) = ( reward=1.0, state=[0.1065114  0.14027398 0.05449564 0.33707593], done=False, info={} )
# I0730 17:16:37.250013 18300 easyenv.py:86] #0   7.42  [totalReward=  42.0] executing step( 1 ) = ( reward=1.0, state=[0.10931688 0.33457979 0.06123716 0.06206368], done=False, info={} )
# I0730 17:16:37.255334 18300 easyenv.py:86] #0   7.43  [totalReward=  43.0] executing step( 1 ) = ( reward=1.0, state=[ 0.11600848  0.52877271  0.06247843 -0.21068724], done=False, info={} )
# I0730 17:16:37.261815 18300 easyenv.py:86] #0   7.44  [totalReward=  44.0] executing step( 1 ) = ( reward=1.0, state=[ 0.12658393  0.72294828  0.05826469 -0.48302558], done=False, info={} )
# I0730 17:16:37.266800 18300 easyenv.py:86] #0   7.45  [totalReward=  45.0] executing step( 0 ) = ( reward=1.0, state=[ 0.1410429   0.52705447  0.04860418 -0.17256337], done=False, info={} )
# I0730 17:16:37.272805 18300 easyenv.py:86] #0   7.46  [totalReward=  46.0] executing step( 0 ) = ( reward=1.0, state=[0.15158399 0.33127179 0.04515291 0.13504784], done=False, info={} )
# I0730 17:16:37.277850 18300 easyenv.py:86] #0   7.47  [totalReward=  47.0] executing step( 0 ) = ( reward=1.0, state=[0.15820942 0.13553314 0.04785387 0.44162701], done=False, info={} )
# I0730 17:16:37.282799 18300 easyenv.py:86] #0   7.48  [totalReward=  48.0] executing step( 0 ) = ( reward=1.0, state=[ 0.16092008 -0.06023217  0.05668641  0.74900249], done=False, info={} )
# I0730 17:16:37.289495 18300 easyenv.py:86] #0   7.49  [totalReward=  49.0] executing step( 0 ) = ( reward=1.0, state=[ 0.15971544 -0.25608834  0.07166646  1.05897173], done=False, info={} )
# I0730 17:16:37.293499 18300 easyenv.py:86] #0   7.50  [totalReward=  50.0] executing step( 1 ) = ( reward=1.0, state=[ 0.15459367 -0.06198516  0.09284589  0.78961624], done=False, info={} )
# I0730 17:16:37.298498 18300 easyenv.py:86] #0   7.51  [totalReward=  51.0] executing step( 1 ) = ( reward=1.0, state=[0.15335397 0.13174744 0.10863821 0.52752647], done=False, info={} )
# I0730 17:16:37.302891 18300 easyenv.py:86] #0   7.52  [totalReward=  52.0] executing step( 0 ) = ( reward=1.0, state=[ 0.15598892 -0.06472188  0.11918874  0.85236991], done=False, info={} )
# I0730 17:16:37.308887 18300 easyenv.py:86] #0   7.53  [totalReward=  53.0] executing step( 1 ) = ( reward=1.0, state=[0.15469448 0.12859117 0.13623614 0.59941614], done=False, info={} )
# I0730 17:16:37.312887 18300 easyenv.py:86] #0   7.54  [totalReward=  54.0] executing step( 0 ) = ( reward=1.0, state=[ 0.15726631 -0.06814738  0.14822447  0.93171919], done=False, info={} )
# I0730 17:16:37.317892 18300 easyenv.py:86] #0   7.55  [totalReward=  55.0] executing step( 0 ) = ( reward=1.0, state=[ 0.15590336 -0.26492498  0.16685885  1.26706765], done=False, info={} )
# I0730 17:16:37.323678 18300 easyenv.py:86] #0   7.56  [totalReward=  56.0] executing step( 1 ) = ( reward=1.0, state=[ 0.15060486 -0.07228055  0.1922002   1.03094354], done=False, info={} )
# I0730 17:16:37.328482 18300 easyenv.py:86] #0   7.57  [totalReward=  57.0] executing step( 0 ) = ( reward=1.0, state=[ 0.14915925 -0.26936728  0.21281907  1.3772896 ], done=True, info={} )
# I0730 17:16:37.329230 18300 easyenv.py:86] #0   7.57  [totalReward=  57.0] game over
# I0730 17:16:37.333812 18300 easyenv.py:86] #0   7.57  [totalReward=  57.0] executing reset(...)
# I0730 17:16:37.339861 18300 easyenv.py:86] #0   8.1   [totalReward=   1.0] executing step( 0 ) = ( reward=1.0, state=[-0.03357433 -0.19855889 -0.03574645  0.2840581 ], done=False, info={} )
# I0730 17:16:37.344861 18300 easyenv.py:86] #0   8.2   [totalReward=   2.0] executing step( 0 ) = ( reward=1.0, state=[-0.03754551 -0.39315325 -0.03006529  0.56525595], done=False, info={} )
# I0730 17:16:37.349436 18300 easyenv.py:86] #0   8.3   [totalReward=   3.0] executing step( 1 ) = ( reward=1.0, state=[-0.04540858 -0.19762268 -0.01876017  0.26325478], done=False, info={} )
# I0730 17:16:37.353440 18300 easyenv.py:86] #0   8.4   [totalReward=   4.0] executing step( 0 ) = ( reward=1.0, state=[-0.04936103 -0.39247189 -0.01349507  0.54996201], done=False, info={} )
# I0730 17:16:37.358324 18300 easyenv.py:86] #0   8.5   [totalReward=   5.0] executing step( 1 ) = ( reward=1.0, state=[-0.05721047 -0.19716301 -0.00249583  0.25305793], done=False, info={} )
# I0730 17:16:37.362874 18300 easyenv.py:86] #0   8.6   [totalReward=   6.0] executing step( 0 ) = ( reward=1.0, state=[-0.06115373 -0.39224924  0.00256533  0.54495258], done=False, info={} )
# I0730 17:16:37.367951 18300 easyenv.py:86] #0   8.7   [totalReward=   7.0] executing step( 0 ) = ( reward=1.0, state=[-0.06899871 -0.58740714  0.01346438  0.83844268], done=False, info={} )
# I0730 17:16:37.372963 18300 easyenv.py:86] #0   8.8   [totalReward=   8.0] executing step( 0 ) = ( reward=1.0, state=[-0.08074686 -0.78271034  0.03023323  1.13532934], done=False, info={} )
# I0730 17:16:37.376965 18300 easyenv.py:86] #0   8.9   [totalReward=   9.0] executing step( 0 ) = ( reward=1.0, state=[-0.09640106 -0.97821453  0.05293982  1.43733882], done=False, info={} )
# I0730 17:16:37.381314 18300 easyenv.py:86] #0   8.10  [totalReward=  10.0] executing step( 1 ) = ( reward=1.0, state=[-0.11596535 -0.78378358  0.08168659  1.16165802], done=False, info={} )
# I0730 17:16:37.387958 18300 easyenv.py:86] #0   8.11  [totalReward=  11.0] executing step( 0 ) = ( reward=1.0, state=[-0.13164103 -0.97986888  0.10491975  1.47879437], done=False, info={} )
# I0730 17:16:37.392329 18300 easyenv.py:86] #0   8.12  [totalReward=  12.0] executing step( 0 ) = ( reward=1.0, state=[-0.1512384  -1.1761036   0.13449564  1.80231764], done=False, info={} )
# I0730 17:16:37.397329 18300 easyenv.py:86] #0   8.13  [totalReward=  13.0] executing step( 1 ) = ( reward=1.0, state=[-0.17476047 -0.98271681  0.17054199  1.55427976], done=False, info={} )
# I0730 17:16:37.406333 18300 easyenv.py:86] #0   8.14  [totalReward=  14.0] executing step( 1 ) = ( reward=1.0, state=[-0.19441481 -0.7899997   0.20162759  1.31929439], done=False, info={} )
# I0730 17:16:37.410469 18300 easyenv.py:86] #0   8.15  [totalReward=  15.0] executing step( 0 ) = ( reward=1.0, state=[-0.21021481 -0.98701733  0.22801348  1.66771171], done=True, info={} )
# I0730 17:16:37.410469 18300 easyenv.py:86] #0   8.15  [totalReward=  15.0] game over
# I0730 17:16:37.414472 18300 easyenv.py:86] #0   8.15  [totalReward=  15.0] executing reset(...)
# I0730 17:16:37.419930 18300 easyenv.py:86] #0   9.1   [totalReward=   1.0] executing step( 0 ) = ( reward=1.0, state=[-0.0068129  -0.14995703 -0.04764749  0.258246  ], done=False, info={} )
# I0730 17:16:37.424338 18300 easyenv.py:86] #0   9.2   [totalReward=   2.0] executing step( 1 ) = ( reward=1.0, state=[-0.00981204  0.04581163 -0.04248257 -0.04907678], done=False, info={} )
# I0730 17:16:37.428472 18300 easyenv.py:86] #0   9.3   [totalReward=   3.0] executing step( 0 ) = ( reward=1.0, state=[-0.0088958  -0.14867623 -0.04346411  0.22990567], done=False, info={} )
# I0730 17:16:37.432488 18300 easyenv.py:86] #0   9.4   [totalReward=   4.0] executing step( 1 ) = ( reward=1.0, state=[-0.01186933  0.047039   -0.038866   -0.07616435], done=False, info={} )
# I0730 17:16:37.437486 18300 easyenv.py:86] #0   9.5   [totalReward=   5.0] executing step( 0 ) = ( reward=1.0, state=[-0.01092855 -0.14750484 -0.04038928  0.20400732], done=False, info={} )
# I0730 17:16:37.441475 18300 easyenv.py:86] #0   9.6   [totalReward=   6.0] executing step( 1 ) = ( reward=1.0, state=[-0.01387865  0.04817074 -0.03630914 -0.1011379 ], done=False, info={} )
# I0730 17:16:37.447905 18300 easyenv.py:86] #0   9.7   [totalReward=   7.0] executing step( 0 ) = ( reward=1.0, state=[-0.01291523 -0.14641255 -0.0383319   0.17987211], done=False, info={} )
# I0730 17:16:37.452423 18300 easyenv.py:86] #0   9.8   [totalReward=   8.0] executing step( 0 ) = ( reward=1.0, state=[-0.01584348 -0.3409656  -0.03473445  0.4602205 ], done=False, info={} )
# I0730 17:16:37.458215 18300 easyenv.py:86] #0   9.9   [totalReward=   9.0] executing step( 0 ) = ( reward=1.0, state=[-0.02266279 -0.53557981 -0.02553004  0.74175586], done=False, info={} )
# I0730 17:16:37.463042 18300 easyenv.py:86] #0   9.10  [totalReward=  10.0] executing step( 1 ) = ( reward=1.0, state=[-0.03337439 -0.34011491 -0.01069493  0.44114903], done=False, info={} )
# I0730 17:16:37.468043 18300 easyenv.py:86] #0   9.11  [totalReward=  11.0] executing step( 0 ) = ( reward=1.0, state=[-0.04017669 -0.53508389 -0.00187195  0.73044153], done=False, info={} )
# I0730 17:16:37.474045 18300 easyenv.py:86] #0   9.12  [totalReward=  12.0] executing step( 0 ) = ( reward=1.0, state=[-0.05087837 -0.73017992  0.01273688  1.02253471], done=False, info={} )
# I0730 17:16:37.479090 18300 easyenv.py:86] #0   9.13  [totalReward=  13.0] executing step( 1 ) = ( reward=1.0, state=[-0.06548196 -0.53522993  0.03318758  0.73387799], done=False, info={} )
# I0730 17:16:37.483092 18300 easyenv.py:86] #0   9.14  [totalReward=  14.0] executing step( 1 ) = ( reward=1.0, state=[-0.07618656 -0.34058184  0.04786514  0.45182198], done=False, info={} )
# I0730 17:16:37.489976 18300 easyenv.py:86] #0   9.15  [totalReward=  15.0] executing step( 0 ) = ( reward=1.0, state=[-0.0829982  -0.53634687  0.05690158  0.7592002 ], done=False, info={} )
# I0730 17:16:37.493975 18300 easyenv.py:86] #0   9.16  [totalReward=  16.0] executing step( 1 ) = ( reward=1.0, state=[-0.09372514 -0.34205321  0.07208558  0.48495143], done=False, info={} )
# I0730 17:16:37.499041 18300 easyenv.py:86] #0   9.17  [totalReward=  17.0] executing step( 1 ) = ( reward=1.0, state=[-0.1005662  -0.14801862  0.08178461  0.21583023], done=False, info={} )
# I0730 17:16:37.504045 18300 easyenv.py:86] #0   9.18  [totalReward=  18.0] executing step( 1 ) = ( reward=1.0, state=[-0.10352657  0.04584469  0.08610122 -0.04997487], done=False, info={} )
# I0730 17:16:37.510790 18300 easyenv.py:86] #0   9.19  [totalReward=  19.0] executing step( 1 ) = ( reward=1.0, state=[-0.10260968  0.23963326  0.08510172 -0.31429843], done=False, info={} )
# I0730 17:16:37.515584 18300 easyenv.py:86] #0   9.20  [totalReward=  20.0] executing step( 1 ) = ( reward=1.0, state=[-0.09781702  0.43344635  0.07881575 -0.57897624], done=False, info={} )
# I0730 17:16:37.520359 18300 easyenv.py:86] #0   9.21  [totalReward=  21.0] executing step( 1 ) = ( reward=1.0, state=[-0.08914809  0.62738042  0.06723622 -0.84582645], done=False, info={} )
# I0730 17:16:37.525357 18300 easyenv.py:86] #0   9.22  [totalReward=  22.0] executing step( 1 ) = ( reward=1.0, state=[-0.07660048  0.82152378  0.0503197  -1.11663093], done=False, info={} )
# I0730 17:16:37.531355 18300 easyenv.py:86] #0   9.23  [totalReward=  23.0] executing step( 1 ) = ( reward=1.0, state=[-0.06017     1.01595049  0.02798708 -1.39311409], done=False, info={} )
# I0730 17:16:37.536358 18300 easyenv.py:86] #0   9.24  [totalReward=  24.0] executing step( 0 ) = ( reward=1.0, state=[-3.98509945e-02  8.20491555e-01  1.24795569e-04 -1.09181338e+00], done=False, info={} )
# I0730 17:16:37.541980 18300 easyenv.py:86] #0   9.25  [totalReward=  25.0] executing step( 0 ) = ( reward=1.0, state=[-0.02344116  0.62536796 -0.02171147 -0.7990913 ], done=False, info={} )
# I0730 17:16:37.546978 18300 easyenv.py:86] #0   9.26  [totalReward=  26.0] executing step( 0 ) = ( reward=1.0, state=[-0.0109338   0.43055048 -0.0376933  -0.51331662], done=False, info={} )
# I0730 17:16:37.552116 18300 easyenv.py:86] #0   9.27  [totalReward=  27.0] executing step( 1 ) = ( reward=1.0, state=[-0.00232279  0.62618248 -0.04795963 -0.81763539], done=False, info={} )
# I0730 17:16:37.557884 18300 easyenv.py:86] #0   9.28  [totalReward=  28.0] executing step( 1 ) = ( reward=1.0, state=[ 0.01020085  0.821927   -0.06431234 -1.12500928], done=False, info={} )
# I0730 17:16:37.562876 18300 easyenv.py:86] #0   9.29  [totalReward=  29.0] executing step( 1 ) = ( reward=1.0, state=[ 0.02663939  1.01783018 -0.08681252 -1.43715135], done=False, info={} )
# I0730 17:16:37.566878 18300 easyenv.py:86] #0   9.30  [totalReward=  30.0] executing step( 0 ) = ( reward=1.0, state=[ 0.046996    0.82387898 -0.11555555 -1.17281097], done=False, info={} )
# I0730 17:16:37.574002 18300 easyenv.py:86] #0   9.31  [totalReward=  31.0] executing step( 0 ) = ( reward=1.0, state=[ 0.06347358  0.63043299 -0.13901177 -0.91847494], done=False, info={} )
# I0730 17:16:37.578268 18300 easyenv.py:86] #0   9.32  [totalReward=  32.0] executing step( 0 ) = ( reward=1.0, state=[ 0.07608224  0.43743619 -0.15738127 -0.67251033], done=False, info={} )
# I0730 17:16:37.582280 18300 easyenv.py:86] #0   9.33  [totalReward=  33.0] executing step( 0 ) = ( reward=1.0, state=[ 0.08483096  0.2448113  -0.17083148 -0.43322327], done=False, info={} )
# I0730 17:16:37.588284 18300 easyenv.py:86] #0   9.34  [totalReward=  34.0] executing step( 0 ) = ( reward=1.0, state=[ 0.08972719  0.05246755 -0.17949594 -0.19888787], done=False, info={} )
# I0730 17:16:37.592842 18300 easyenv.py:86] #0   9.35  [totalReward=  35.0] executing step( 1 ) = ( reward=1.0, state=[ 0.09077654  0.24964205 -0.1834737  -0.54238674], done=False, info={} )
# I0730 17:16:37.599147 18300 easyenv.py:86] #0   9.36  [totalReward=  36.0] executing step( 0 ) = ( reward=1.0, state=[ 0.09576938  0.05750832 -0.19432143 -0.31266249], done=False, info={} )
# I0730 17:16:37.604143 18300 easyenv.py:86] #0   9.37  [totalReward=  37.0] executing step( 1 ) = ( reward=1.0, state=[ 0.09691955  0.25479082 -0.20057468 -0.65978826], done=False, info={} )
# I0730 17:16:37.609129 18300 easyenv.py:86] #0   9.38  [totalReward=  38.0] executing step( 0 ) = ( reward=1.0, state=[ 0.10201536  0.06294147 -0.21377045 -0.43635782], done=True, info={} )
# I0730 17:16:37.610129 18300 easyenv.py:86] #0   9.38  [totalReward=  38.0] game over
# I0730 17:16:37.614154 18300 easyenv.py:86] #0   9.38  [totalReward=  38.0] executing reset(...)
# I0730 17:16:37.619331 18300 easyenv.py:86] #0  10.1   [totalReward=   1.0] executing step( 1 ) = ( reward=1.0, state=[-0.01920685  0.15033781  0.0350094  -0.27207235], done=False, info={} )
# I0730 17:16:37.624351 18300 easyenv.py:86] #0  10.2   [totalReward=   2.0] executing step( 0 ) = ( reward=1.0, state=[-0.0162001  -0.04526575  0.02956795  0.03144386], done=False, info={} )
# I0730 17:16:37.628331 18300 easyenv.py:86] #0  10.3   [totalReward=   3.0] executing step( 1 ) = ( reward=1.0, state=[-0.01710541  0.14941998  0.03019683 -0.25176537], done=False, info={} )
# I0730 17:16:37.633327 18300 easyenv.py:86] #0  10.4   [totalReward=   4.0] executing step( 1 ) = ( reward=1.0, state=[-0.01411701  0.34409801  0.02516152 -0.53477277], done=False, info={} )
# I0730 17:16:37.640332 18300 easyenv.py:86] #0  10.5   [totalReward=   5.0] executing step( 0 ) = ( reward=1.0, state=[-0.00723505  0.14863143  0.01446606 -0.23426901], done=False, info={} )
# I0730 17:16:37.644330 18300 easyenv.py:86] #0  10.6   [totalReward=   6.0] executing step( 1 ) = ( reward=1.0, state=[-0.00426242  0.34354373  0.00978068 -0.522354  ], done=False, info={} )
# I0730 17:16:37.650154 18300 easyenv.py:86] #0  10.7   [totalReward=   7.0] executing step( 1 ) = ( reward=1.0, state=[ 2.60845036e-03  5.38526662e-01 -6.66397390e-04 -8.11938931e-01], done=False, info={} )
# I0730 17:16:37.656145 18300 easyenv.py:86] #0  10.8   [totalReward=   8.0] executing step( 1 ) = ( reward=1.0, state=[ 0.01337898  0.73365774 -0.01690518 -1.1048314 ], done=False, info={} )
# I0730 17:16:37.660507 18300 easyenv.py:86] #0  10.9   [totalReward=   9.0] executing step( 1 ) = ( reward=1.0, state=[ 0.02805214  0.92899787 -0.0390018  -1.40276962], done=False, info={} )
# I0730 17:16:37.665572 18300 easyenv.py:86] #0  10.10  [totalReward=  10.0] executing step( 1 ) = ( reward=1.0, state=[ 0.0466321   1.12458198 -0.0670572  -1.7073863 ], done=False, info={} )
# I0730 17:16:37.670904 18300 easyenv.py:86] #0  10.11  [totalReward=  11.0] executing step( 0 ) = ( reward=1.0, state=[ 0.06912374  0.93029211 -0.10120492 -1.43630653], done=False, info={} )
# I0730 17:16:37.675907 18300 easyenv.py:86] #0  10.12  [totalReward=  12.0] executing step( 0 ) = ( reward=1.0, state=[ 0.08772958  0.73655305 -0.12993105 -1.17688843], done=False, info={} )
# I0730 17:16:37.679723 18300 easyenv.py:86] #0  10.13  [totalReward=  13.0] executing step( 0 ) = ( reward=1.0, state=[ 0.10246064  0.54333586 -0.15346882 -0.92759797], done=False, info={} )
# ...
# I0730 17:17:14.412491 18300 easyenv.py:86] #0 295.11  [totalReward=  11.0] game over
# I0730 17:17:14.422492 18300 easyenv.py:86] #0 295.11  [totalReward=  11.0] executing reset(...)
# I0730 17:17:14.432495 18300 easyenv.py:86] #0 296.1   [totalReward=   1.0] executing step( 0 ) = ( reward=1.0, state=[-0.00237538 -0.20853607  0.03790902  0.29725001], done=False, info={} )
# I0730 17:17:14.442488 18300 easyenv.py:86] #0 296.2   [totalReward=   2.0] executing step( 0 ) = ( reward=1.0, state=[-0.00654611 -0.40417734  0.04385402  0.60164366], done=False, info={} )
# I0730 17:17:14.453480 18300 easyenv.py:86] #0 296.3   [totalReward=   3.0] executing step( 0 ) = ( reward=1.0, state=[-0.01462965 -0.59988442  0.05588689  0.90781097], done=False, info={} )
# I0730 17:17:14.464500 18300 easyenv.py:86] #0 296.4   [totalReward=   4.0] executing step( 0 ) = ( reward=1.0, state=[-0.02662734 -0.79571658  0.07404311  1.21752279], done=False, info={} )
# I0730 17:17:14.474219 18300 easyenv.py:86] #0 296.5   [totalReward=   5.0] executing step( 0 ) = ( reward=1.0, state=[-0.04254167 -0.99171108  0.09839356  1.53245781], done=False, info={} )
# I0730 17:17:14.483224 18300 easyenv.py:86] #0 296.6   [totalReward=   6.0] executing step( 1 ) = ( reward=1.0, state=[-0.06237589 -0.79790292  0.12904272  1.27203273], done=False, info={} )
# I0730 17:17:14.492219 18300 easyenv.py:86] #0 296.7   [totalReward=   7.0] executing step( 0 ) = ( reward=1.0, state=[-0.07833395 -0.99441381  0.15448337  1.60218159], done=False, info={} )
# I0730 17:17:14.501219 18300 easyenv.py:86] #0 296.8   [totalReward=   8.0] executing step( 0 ) = ( reward=1.0, state=[-0.09822223 -1.1909903   0.18652701  1.93877251], done=False, info={} )
# I0730 17:17:14.510219 18300 easyenv.py:86] #0 296.9   [totalReward=   9.0] executing step( 0 ) = ( reward=1.0, state=[-0.12204203 -1.38755102  0.22530246  2.28302083], done=True, info={} )
# I0730 17:17:14.511594 18300 easyenv.py:86] #0 296.9   [totalReward=   9.0] game over
# I0730 17:17:14.520621 18300 easyenv.py:86] #0 296.9   [totalReward=   9.0] executing reset(...)
# I0730 17:17:14.528620 18300 easyenv.py:86] #0 297.1   [totalReward=   1.0] executing step( 0 ) = ( reward=1.0, state=[ 0.0368547  -0.22286147  0.00295772  0.33402282], done=False, info={} )
# I0730 17:17:14.538623 18300 easyenv.py:86] #0 297.2   [totalReward=   2.0] executing step( 0 ) = ( reward=1.0, state=[ 0.03239747 -0.41802539  0.00963818  0.62763699], done=False, info={} )
# I0730 17:17:14.547251 18300 easyenv.py:86] #0 297.3   [totalReward=   3.0] executing step( 0 ) = ( reward=1.0, state=[ 0.02403696 -0.61328053  0.02219092  0.92333967], done=False, info={} )
# I0730 17:17:14.558847 18300 easyenv.py:86] #0 297.4   [totalReward=   4.0] executing step( 0 ) = ( reward=1.0, state=[ 0.01177135 -0.80869513  0.04065771  1.222913  ], done=False, info={} )
# I0730 17:17:14.566862 18300 easyenv.py:86] #0 297.5   [totalReward=   5.0] executing step( 0 ) = ( reward=1.0, state=[-0.00440255 -1.00431658  0.06511597  1.52805275], done=False, info={} )
# I0730 17:17:14.577546 18300 easyenv.py:86] #0 297.6   [totalReward=   6.0] executing step( 0 ) = ( reward=1.0, state=[-0.02448889 -1.20016084  0.09567702  1.84032714], done=False, info={} )
# I0730 17:17:14.588546 18300 easyenv.py:86] #0 297.7   [totalReward=   7.0] executing step( 0 ) = ( reward=1.0, state=[-0.0484921  -1.39620002  0.13248357  2.16112716], done=False, info={} )
# I0730 17:17:14.596548 18300 easyenv.py:86] #0 297.8   [totalReward=   8.0] executing step( 0 ) = ( reward=1.0, state=[-0.0764161  -1.59234748  0.17570611  2.49160639], done=False, info={} )
# I0730 17:17:14.607546 18300 easyenv.py:86] #0 297.9   [totalReward=   9.0] executing step( 0 ) = ( reward=1.0, state=[-0.10826305 -1.78844061  0.22553824  2.83260952], done=True, info={} )
# I0730 17:17:14.607546 18300 easyenv.py:86] #0 297.9   [totalReward=   9.0] game over
# I0730 17:17:14.617549 18300 easyenv.py:86] #0 297.9   [totalReward=   9.0] executing reset(...)
# I0730 17:17:14.626743 18300 easyenv.py:86] #0 298.1   [totalReward=   1.0] executing step( 0 ) = ( reward=1.0, state=[-0.02824638 -0.15575957 -0.03757519  0.30871279], done=False, info={} )
# I0730 17:17:14.640743 18300 easyenv.py:86] #0 298.2   [totalReward=   2.0] executing step( 0 ) = ( reward=1.0, state=[-0.03136157 -0.35032655 -0.03140094  0.58931274], done=False, info={} )
# I0730 17:17:14.650269 18300 easyenv.py:86] #0 298.3   [totalReward=   3.0] executing step( 0 ) = ( reward=1.0, state=[-0.0383681  -0.54499506 -0.01961468  0.87194119], done=False, info={} )
# I0730 17:17:14.660444 18300 easyenv.py:86] #0 298.4   [totalReward=   4.0] executing step( 0 ) = ( reward=1.0, state=[-0.049268   -0.73984484 -0.00217586  1.1583933 ], done=False, info={} )
# I0730 17:17:14.673441 18300 easyenv.py:86] #0 298.5   [totalReward=   5.0] executing step( 0 ) = ( reward=1.0, state=[-0.0640649  -0.93493837  0.02099201  1.4503932 ], done=False, info={} )
# I0730 17:17:14.682448 18300 easyenv.py:86] #0 298.6   [totalReward=   6.0] executing step( 0 ) = ( reward=1.0, state=[-0.08276366 -1.13031191  0.04999987  1.74956014], done=False, info={} )
# I0730 17:17:14.692442 18300 easyenv.py:86] #0 298.7   [totalReward=   7.0] executing step( 0 ) = ( reward=1.0, state=[-0.1053699  -1.32596472  0.08499107  2.05736643], done=False, info={} )
# I0730 17:17:14.702458 18300 easyenv.py:86] #0 298.8   [totalReward=   8.0] executing step( 0 ) = ( reward=1.0, state=[-0.1318892  -1.52184588  0.1261384   2.37508489], done=False, info={} )
# I0730 17:17:14.711445 18300 easyenv.py:86] #0 298.9   [totalReward=   9.0] executing step( 0 ) = ( reward=1.0, state=[-0.16232611 -1.71783838  0.1736401   2.70372436], done=False, info={} )
# I0730 17:17:14.720444 18300 easyenv.py:86] #0 298.10  [totalReward=  10.0] executing step( 0 ) = ( reward=1.0, state=[-0.19668288 -1.91374081  0.22771459  3.04395319], done=True, info={} )
# I0730 17:17:14.721441 18300 easyenv.py:86] #0 298.10  [totalReward=  10.0] game over
# I0730 17:17:14.729443 18300 easyenv.py:86] #0 298.10  [totalReward=  10.0] executing reset(...)
# I0730 17:17:14.739445 18300 easyenv.py:86] #0 299.1   [totalReward=   1.0] executing step( 0 ) = ( reward=1.0, state=[-0.00445012 -0.21511325  0.00291168  0.28493393], done=False, info={} )
# I0730 17:17:14.749503 18300 easyenv.py:86] #0 299.2   [totalReward=   2.0] executing step( 0 ) = ( reward=1.0, state=[-0.00875239 -0.4102766   0.00861036  0.57853375], done=False, info={} )
# I0730 17:17:14.761712 18300 easyenv.py:86] #0 299.3   [totalReward=   3.0] executing step( 0 ) = ( reward=1.0, state=[-0.01695792 -0.60551816  0.02018103  0.87391665], done=False, info={} )
# I0730 17:17:14.771672 18300 easyenv.py:86] #0 299.4   [totalReward=   4.0] executing step( 0 ) = ( reward=1.0, state=[-0.02906828 -0.8009086   0.03765937  1.17287545], done=False, info={} )
# I0730 17:17:14.779712 18300 easyenv.py:86] #0 299.5   [totalReward=   5.0] executing step( 0 ) = ( reward=1.0, state=[-0.04508645 -0.99649932  0.06111687  1.47712274], done=False, info={} )
# I0730 17:17:14.792302 18300 easyenv.py:86] #0 299.6   [totalReward=   6.0] executing step( 0 ) = ( reward=1.0, state=[-0.06501644 -1.19231213  0.09065933  1.78825074], done=False, info={} )
# I0730 17:17:14.802386 18300 easyenv.py:86] #0 299.7   [totalReward=   7.0] executing step( 0 ) = ( reward=1.0, state=[-0.08886268 -1.38832713  0.12642434  2.10768312], done=False, info={} )
# I0730 17:17:14.811385 18300 easyenv.py:86] #0 299.8   [totalReward=   8.0] executing step( 0 ) = ( reward=1.0, state=[-0.11662922 -1.58446831  0.16857801  2.43661663], done=False, info={} )
# I0730 17:17:14.825464 18300 easyenv.py:86] #0 299.9   [totalReward=   9.0] executing step( 0 ) = ( reward=1.0, state=[-0.14831859 -1.78058658  0.21731034  2.77595139], done=True, info={} )
# I0730 17:17:14.826832 18300 easyenv.py:86] #0 299.9   [totalReward=   9.0] game over
# I0730 17:17:14.837486 18300 easyenv.py:86] #0 299.9   [totalReward=   9.0] executing reset(...)
# I0730 17:17:14.845683 18300 easyenv.py:86] #0 300.1   [totalReward=   1.0] executing step( 0 ) = ( reward=1.0, state=[ 0.04008163 -0.23276311  0.00824171  0.32031173], done=False, info={} )
# I0730 17:17:14.856218 18300 easyenv.py:86] #0 300.2   [totalReward=   2.0] executing step( 0 ) = ( reward=1.0, state=[ 0.03542636 -0.42800146  0.01464795  0.61558234], done=False, info={} )
# I0730 17:17:14.866296 18300 easyenv.py:86] #0 300.3   [totalReward=   3.0] executing step( 0 ) = ( reward=1.0, state=[ 0.02686633 -0.62332497  0.02695959  0.91284252], done=False, info={} )
# I0730 17:17:14.876317 18300 easyenv.py:86] #0 300.4   [totalReward=   4.0] executing step( 0 ) = ( reward=1.0, state=[ 0.01439983 -0.81880107  0.04521644  1.21387528], done=False, info={} )
# I0730 17:17:14.887603 18300 easyenv.py:86] #0 300.5   [totalReward=   5.0] executing step( 0 ) = ( reward=1.0, state=[-0.00197619 -1.01447638  0.06949395  1.52037734], done=False, info={} )
# I0730 17:17:14.897865 18300 easyenv.py:86] #0 300.6   [totalReward=   6.0] executing step( 0 ) = ( reward=1.0, state=[-0.02226571 -1.21036606  0.0999015   1.83391741], done=False, info={} )
# I0730 17:17:14.909375 18300 easyenv.py:86] #0 300.7   [totalReward=   7.0] executing step( 0 ) = ( reward=1.0, state=[-0.04647304 -1.40644127  0.13657984  2.15588598], done=False, info={} )
# I0730 17:17:14.920383 18300 easyenv.py:86] #0 300.8   [totalReward=   8.0] executing step( 0 ) = ( reward=1.0, state=[-0.07460186 -1.60261421  0.17969756  2.48743484], done=False, info={} )
# I0730 17:17:14.930307 18300 easyenv.py:86] #0 300.9   [totalReward=   9.0] executing step( 0 ) = ( reward=1.0, state=[-0.10665414 -1.79872087  0.22944626  2.82940543], done=True, info={} )
# I0730 17:17:14.932310 18300 easyenv.py:86] #0 300.9   [totalReward=   9.0] game over
# I0730 17:17:14.946385 18300 easyenv.py:86] #0 300.9   [totalReward=   9.0] executing reset(...)
# I0730 17:17:14.957133 18300 easyenv.py:86] #0 301.1   [totalReward=   1.0] executing step( 1 ) = ( reward=1.0, state=[-0.0440944   0.23612818 -0.04961085 -0.35473131], done=False, info={} )
# I0730 17:17:14.967675 18300 easyenv.py:86] #0 301.2   [totalReward=   2.0] executing step( 0 ) = ( reward=1.0, state=[-0.03937184  0.04174544 -0.05670547 -0.07809556], done=False, info={} )
# I0730 17:17:14.976589 18300 easyenv.py:86] #0 301.3   [totalReward=   3.0] executing step( 0 ) = ( reward=1.0, state=[-0.03853693 -0.15251969 -0.05826739  0.1961713 ], done=False, info={} )
# I0730 17:17:14.984593 18300 easyenv.py:86] #0 301.4   [totalReward=   4.0] executing step( 0 ) = ( reward=1.0, state=[-0.04158732 -0.34676188 -0.05434396  0.4699192 ], done=False, info={} )
# I0730 17:17:14.992591 18300 easyenv.py:86] #0 301.5   [totalReward=   5.0] executing step( 0 ) = ( reward=1.0, state=[-0.04852256 -0.54107575 -0.04494558  0.74499045], done=False, info={} )
# I0730 17:17:15.004362 18300 easyenv.py:86] #0 301.6   [totalReward=   6.0] executing step( 0 ) = ( reward=1.0, state=[-0.05934408 -0.73554959 -0.03004577  1.02319706], done=False, info={} )
# I0730 17:17:15.012359 18300 easyenv.py:86] #0 301.7   [totalReward=   7.0] executing step( 0 ) = ( reward=1.0, state=[-0.07405507 -0.93025872 -0.00958183  1.30629682], done=False, info={} )
# I0730 17:17:15.025429 18300 easyenv.py:86] #0 301.8   [totalReward=   8.0] executing step( 0 ) = ( reward=1.0, state=[-0.09266024 -1.12525791  0.01654411  1.59596515], done=False, info={} )
# I0730 17:17:15.035313 18300 easyenv.py:86] #0 301.9   [totalReward=   9.0] executing step( 0 ) = ( reward=1.0, state=[-0.1151654  -1.32057206  0.04846341  1.89376003], done=False, info={} )
# I0730 17:17:15.047544 18300 easyenv.py:86] #0 301.10  [totalReward=  10.0] executing step( 0 ) = ( reward=1.0, state=[-0.14157684 -1.51618487  0.08633861  2.2010774 ], done=False, info={} )
# I0730 17:17:15.059540 18300 easyenv.py:86] #0 301.11  [totalReward=  11.0] executing step( 0 ) = ( reward=1.0, state=[-0.17190054 -1.71202476  0.13036016  2.51909506], done=False, info={} )
# I0730 17:17:15.072643 18300 easyenv.py:86] #0 301.12  [totalReward=  12.0] executing step( 0 ) = ( reward=1.0, state=[-0.20614103 -1.90794813  0.18074206  2.84870397], done=False, info={} )
# I0730 17:17:15.082645 18300 easyenv.py:86] #0 301.13  [totalReward=  13.0] executing step( 0 ) = ( reward=1.0, state=[-0.2443     -2.10372003  0.23771614  3.19042762], done=True, info={} )
# I0730 17:17:15.084486 18300 easyenv.py:86] #0 301.13  [totalReward=  13.0] game over
# I0730 17:17:15.092645 18300 easyenv.py:86] #0 301.13  [totalReward=  13.0] executing reset(...)
# I0730 17:17:15.101640 18300 easyenv.py:86] #0 302.1   [totalReward=   1.0] executing step( 0 ) = ( reward=1.0, state=[-0.00880244 -0.22509301 -0.01314524  0.27403792], done=False, info={} )
# I0730 17:17:15.110638 18300 easyenv.py:86] #0 302.2   [totalReward=   2.0] executing step( 0 ) = ( reward=1.0, state=[-0.0133043  -0.42002496 -0.00766448  0.56254599], done=False, info={} )
# I0730 17:17:15.121393 18300 easyenv.py:86] #0 302.3   [totalReward=   3.0] executing step( 0 ) = ( reward=1.0, state=[-0.0217048  -0.61503852  0.00358643  0.85280441], done=False, info={} )
# I0730 17:17:15.130313 18300 easyenv.py:86] #0 302.4   [totalReward=   4.0] executing step( 0 ) = ( reward=1.0, state=[-0.03400557 -0.81020918  0.02064252  1.14661292], done=False, info={} )
# I0730 17:17:15.142396 18300 easyenv.py:86] #0 302.5   [totalReward=   5.0] executing step( 0 ) = ( reward=1.0, state=[-0.05020975 -1.00559453  0.04357478  1.44569697], done=False, info={} )
# I0730 17:17:15.144392 18300 agents.py:110] training    3 of 3   : executing  iter(replay_buffer.as_dataset)
# I0730 17:17:15.146391 18300 agents.py:110] training    3 of 3   : executing  tf_agent.train(...)
# I0730 17:17:15.149454 18300 agents.py:115] training    3 of 3   : completed tf_agent.train(...) =    0.000 [loss]
# I0730 17:17:15.151450 18300 agents.py:110] current policy       : evaluating... [1 episodes]
# I0730 17:17:15.151450 18300 easyenv.py:86] #1   3.11  [totalReward=  11.0] executing reset(...)
# I0730 17:17:15.158451 18300 easyenv.py:86] #1   4.1   [totalReward=   1.0] executing step( 0 ) = ( reward=1.0, state=[ 0.03258672 -0.21477288  0.02117187  0.32243896], done=False, info={} )
# I0730 17:17:15.164456 18300 easyenv.py:86] #1   4.2   [totalReward=   2.0] executing step( 0 ) = ( reward=1.0, state=[ 0.02829126 -0.41018982  0.02762065  0.62172274], done=False, info={} )
# I0730 17:17:15.172357 18300 easyenv.py:86] #1   4.3   [totalReward=   3.0] executing step( 0 ) = ( reward=1.0, state=[ 0.02008746 -0.60568637  0.04005511  0.92297514], done=False, info={} )
# I0730 17:17:15.177356 18300 easyenv.py:86] #1   4.4   [totalReward=   4.0] executing step( 0 ) = ( reward=1.0, state=[ 0.00797374 -0.80132592  0.05851461  1.22797214], done=False, info={} )
# I0730 17:17:15.184705 18300 easyenv.py:86] #1   4.5   [totalReward=   5.0] executing step( 0 ) = ( reward=1.0, state=[-0.00805278 -0.9971501   0.08307405  1.53839917], done=False, info={} )
# I0730 17:17:15.189731 18300 easyenv.py:86] #1   4.6   [totalReward=   6.0] executing step( 0 ) = ( reward=1.0, state=[-0.02799578 -1.19316763  0.11384204  1.85580715], done=False, info={} )
# I0730 17:17:15.194739 18300 easyenv.py:86] #1   4.7   [totalReward=   7.0] executing step( 0 ) = ( reward=1.0, state=[-0.05185914 -1.38934126  0.15095818  2.18156016], done=False, info={} )
# I0730 17:17:15.201790 18300 easyenv.py:86] #1   4.8   [totalReward=   8.0] executing step( 0 ) = ( reward=1.0, state=[-0.07964596 -1.58557245  0.19458938  2.51677279], done=False, info={} )
# I0730 17:17:15.207786 18300 easyenv.py:86] #1   4.9   [totalReward=   9.0] executing step( 0 ) = ( reward=1.0, state=[-0.11135741 -1.78168374  0.24492484  2.86223688], done=True, info={} )
# I0730 17:17:15.207786 18300 easyenv.py:86] #1   4.9   [totalReward=   9.0] game over
# I0730 17:17:15.217786 18300 agents.py:115] current policy       : avg_reward=9.000, avg_steps=9.000

# %% [markdown]
# Note that rewards and step count are equal. That's because the CartPole environment doles out 1 reward point for
# each successful step, and stops after the first failed step.

# %% [markdown]
# ## Default training with a movie (on a self-defined network)

# %%
from easyagents.tfagents import PpoAgent

ppoAgent = DqnAgent( gym_env_name = 'CartPole-v0', fc_layers=(100, 50, 25) )
ppoAgent.train()

# %%
ppoAgent = PpoAgent( gym_env_name = 'CartPole-v0', fc_layers=(100, 50, 25) )
ppoAgent.train()

# %% [markdown]
# The fc_layers argument defines the policy's neural network architecture. Here we use 3 fully connected layers
# with 100 neurons in the first, 50 in the second and 25 in the final layer.
# By default fc_layers=(75,75) is used.
#
# The 'sum of rewards' - as well as the steps - plot shows the evaluation of the current policy.
# The line depicts the average sum of rewards over all games played during evaluation,
# the area the corresponding min and max values.
#
# Note:
# The policy evaluation is controlled through the Agent's training argument.
# By default 10 evaluation episodes are used.
# The training configuration TrainingFast() in the previous cell is set to 1 evaluation episode.
# Thus min, max and average are all equal and hence no area is visible.

# %% [markdown]
# ### Replot the training statistics

# %%
_ = ppoAgent.plot_episodes()

# %% [markdown]
# ### Visualize the trained policy playing a game

# %%
ppoAgent.render_episodes_to_jupyter(num_episodes=1, fps=50)

# %% [markdown]
# ## Next: Custom training (self-defined training scheme & logging)
#
# * see [Berater on colab](https://colab.research.google.com/github/christianhidber/easyagents/blob/master/jupyter_notebooks/easyagents_berater.ipynb)
#   (an example of a gym environment implementation based on a routing problem)
